# %%
#! pip install nltk

# %%
import nltk
nltk.download("vader_lexicon")
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\HP/nltk_data...
# True

# %%
import re # Regular Expression
from nltk.tokenize import word_tokenize 
from nltk.corpus import stopwords

# %%
sample_text="""The WikiQA corpus is a new publicly available set of question and sentence pairs, collected and annotated for research on open-domain question answering. In order to reflect the true information need of general users, we used Bing query logs as the question source. Each question is linked to a Wikipedia page that potentially has the answer. Because the summary section of a Wikipedia page provides the basic and usually most important information about the topic, we used sentences in this section as the candidate answers. With the help of crowdsourcing, we included 3,047 questions and 29,258 sentences in the dataset, where 1,473 sentences were labeled as answer sentences to their corresponding questions. More detail of this corpus can be found in our EMNLP-2015 paper, "WikiQA: A Challenge Dataset for Open-Domain Question Answering" [Yang et al. 2015]. In addition, this download also includes the experimental results in the paper, an evaluation script for judging the "answer triggering" task, as well as the answer phrases labeled by the authors of the paper."""

# %%
sample_text = sample_text.lower()
sample_text
# Out:
# 'the wikiqa corpus is a new publicly available set of question and sentence pairs, collected and annotated for research on open-domain question answering. in order to reflect the true information need of general users, we used bing query logs as the question source. each question is linked to a wikipedia page that potentially has the answer. because the summary section of a wikipedia page provides the basic and usually most important information about the topic, we used sentences in this section as the candidate answers. with the help of crowdsourcing, we included 3,047 questions and 29,258 sentences in the dataset, where 1,473 sentences were labeled as answer sentences to their corresponding questions. more detail of this corpus can be found in our emnlp-2015 paper, "wikiqa: a challenge dataset for open-domain question answering" [yang et al. 2015]. in addition, this download also includes the experimental results in the paper, an evaluation script for judging the "answer triggering" task, as well as the answer phrases labeled by the authors of the paper.'

# %%
sample_tokens = word_tokenize(sample_text)
sample_tokens
# Out:
# ['the',
#  'wikiqa',
#  'corpus',
#  'is',
#  'a',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'of',
#  'question',
#  'and',
#  'sentence',
#  'pairs',
#  ',',
#  'collected',
#  'and',
#  'annotated',
#  'for',
#  'research',
#  'on',
#  'open-domain',
#  'question',
#  'answering',
#  '.',
#  'in',
#  'order',
#  'to',
#  'reflect',
#  'the',
#  'true',
#  'information',
#  'need',
#  'of',
#  'general',
#  'users',
#  ',',
#  'we',
#  'used',
#  'bing',
#  'query',
#  'logs',
#  'as',
#  'the',
#  'question',
#  'source',
#  '.',
#  'each',
#  'question',
#  'is',
#  'linked',
#  'to',
#  'a',
#  'wikipedia',
#  'page',
#  'that',
#  'potentially',
#  'has',
#  'the',
#  'answer',
#  '.',
#  'because',
#  'the',
#  'summary',
#  'section',
#  'of',
#  'a',
#  'wikipedia',
#  'page',
#  'provides',
#  'the',
#  'basic',
#  'and',
#  'usually',
#  'most',
#  'important',
#  'information',
#  'about',
#  'the',
#  'topic',
#  ',',
#  'we',
#  'used',
#  'sentences',
#  'in',
#  'this',
#  'section',
#  'as',
#  'the',
#  'candidate',
#  'answers',
#  '.',
#  'with',
#  'the',
#  'help',
#  'of',
#  'crowdsourcing',
#  ',',
#  'we',
#  'included',
#  '3,047',
#  'questions',
#  'and',
#  '29,258',
#  'sentences',
#  'in',
#  'the',
#  'dataset',
#  ',',
#  'where',
#  '1,473',
#  'sentences',
#  'were',
#  'labeled',
#  'as',
#  'answer',
#  'sentences',
#  'to',
#  'their',
#  'corresponding',
#  'questions',
#  '.',
#  'more',
#  'detail',
#  'of',
#  'this',
#  'corpus',
#  'can',
#  'be',
#  'found',
#  'in',
#  'our',
#  'emnlp-2015',
#  'paper',
#  ',',
#  '``',
#  'wikiqa',
#  ':',
#  'a',
#  'challenge',
#  'dataset',
#  'for',
#  'open-domain',
#  'question',
#  'answering',
#  "''",
#  '[',
#  'yang',
#  'et',
#  'al',
#  '.',
#  '2015',
#  ']',
#  '.',
#  'in',
#  'addition',
#  ',',
#  'this',
#  'download',
#  'also',
#  'includes',
#  'the',
#  'experimental',
#  'results',
#  'in',
#  'the',
#  'paper',
#  ',',
#  'an',
#  'evaluation',
#  'script',
#  'for',
#  'judging',
#  'the',
#  '``',
#  'answer',
#  'triggering',
#  "''",
#  'task',
#  ',',
#  'as',
#  'well',
#  'as',
#  'the',
#  'answer',
#  'phrases',
#  'labeled',
#  'by',
#  'the',
#  'authors',
#  'of',
#  'the',
#  'paper',
#  '.']

# %%
import pickle
with open("sample_tokens.pkl","wb") as mf:
    pickle.dump(sample_tokens,mf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pickle
#       2 with open("sample_tokens.pkl","wb") as mf:
# ----> 3     pickle.dump(sample_tokens,mf)
#
# NameError: name 'sample_tokens' is not defined

# %% [markdown]
# # Stopwords removal

# %%
type(stopwords.words('english'))
# Out:
# list

# %%
stop_words = stopwords.words('english')

# %%
stop_words = set(stop_words)

# %%
sr_list = []
for i in sample_tokens:
    if i not in stop_words:
        print(i)
        sr_list.append(i)
# Out:
# wikiqa
# corpus
# new
# publicly
# available
# set
# question
# sentence
# pairs
# ,
# collected
# annotated
# research
# open-domain
# question
# answering
# .
# order
# reflect
# true
# information
# need
# general
# users
# ,
# used
# bing
# query
# logs
# question
# source
# .
# question
# linked
# wikipedia
# page
# potentially
# answer
# .
# summary
# section
# wikipedia
# page
# provides
# basic
# usually
# important
# information
# topic
# ,
# used
# sentences
# section
# candidate
# answers
# .
# help
# crowdsourcing
# ,
# included
# 3,047
# questions
# 29,258
# sentences
# dataset
# ,
# 1,473
# sentences
# labeled
# answer
# sentences
# corresponding
# questions
# .
# detail
# corpus
# found
# emnlp-2015
# paper
# ,
# ``
# wikiqa
# :
# challenge
# dataset
# open-domain
# question
# answering
# ''
# [
# yang
# et
# al
# .
# 2015
# ]
# .
# addition
# ,
# download
# also
# includes
# experimental
# results
# paper
# ,
# evaluation
# script
# judging
# ``
# answer
# triggering
# ''
# task
# ,
# well
# answer
# phrases
# labeled
# authors
# paper
# .

# %%
sr_list = [i for i in sample_tokens if i not in stop_words ]

# %%
sr_list
# Out:
# ['wikiqa',
#  'corpus',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'question',
#  'sentence',
#  'pairs',
#  ',',
#  'collected',
#  'annotated',
#  'research',
#  'open-domain',
#  'question',
#  'answering',
#  '.',
#  'order',
#  'reflect',
#  'true',
#  'information',
#  'need',
#  'general',
#  'users',
#  ',',
#  'used',
#  'bing',
#  'query',
#  'logs',
#  'question',
#  'source',
#  '.',
#  'question',
#  'linked',
#  'wikipedia',
#  'page',
#  'potentially',
#  'answer',
#  '.',
#  'summary',
#  'section',
#  'wikipedia',
#  'page',
#  'provides',
#  'basic',
#  'usually',
#  'important',
#  'information',
#  'topic',
#  ',',
#  'used',
#  'sentences',
#  'section',
#  'candidate',
#  'answers',
#  '.',
#  'help',
#  'crowdsourcing',
#  ',',
#  'included',
#  '3,047',
#  'questions',
#  '29,258',
#  'sentences',
#  'dataset',
#  ',',
#  '1,473',
#  'sentences',
#  'labeled',
#  'answer',
#  'sentences',
#  'corresponding',
#  'questions',
#  '.',
#  'detail',
#  'corpus',
#  'found',
#  'emnlp-2015',
#  'paper',
#  ',',
#  '``',
#  'wikiqa',
#  ':',
#  'challenge',
#  'dataset',
#  'open-domain',
#  'question',
#  'answering',
#  "''",
#  '[',
#  'yang',
#  'et',
#  'al',
#  '.',
#  '2015',
#  ']',
#  '.',
#  'addition',
#  ',',
#  'download',
#  'also',
#  'includes',
#  'experimental',
#  'results',
#  'paper',
#  ',',
#  'evaluation',
#  'script',
#  'judging',
#  '``',
#  'answer',
#  'triggering',
#  "''",
#  'task',
#  ',',
#  'well',
#  'answer',
#  'phrases',
#  'labeled',
#  'authors',
#  'paper',
#  '.']

# %%
sample_tokens
# Out:
# ['the',
#  'wikiqa',
#  'corpus',
#  'is',
#  'a',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'of',
#  'question',
#  'and',
#  'sentence',
#  'pairs',
#  ',',
#  'collected',
#  'and',
#  'annotated',
#  'for',
#  'research',
#  'on',
#  'open-domain',
#  'question',
#  'answering',
#  '.',
#  'in',
#  'order',
#  'to',
#  'reflect',
#  'the',
#  'true',
#  'information',
#  'need',
#  'of',
#  'general',
#  'users',
#  ',',
#  'we',
#  'used',
#  'bing',
#  'query',
#  'logs',
#  'as',
#  'the',
#  'question',
#  'source',
#  '.',
#  'each',
#  'question',
#  'is',
#  'linked',
#  'to',
#  'a',
#  'wikipedia',
#  'page',
#  'that',
#  'potentially',
#  'has',
#  'the',
#  'answer',
#  '.',
#  'because',
#  'the',
#  'summary',
#  'section',
#  'of',
#  'a',
#  'wikipedia',
#  'page',
#  'provides',
#  'the',
#  'basic',
#  'and',
#  'usually',
#  'most',
#  'important',
#  'information',
#  'about',
#  'the',
#  'topic',
#  ',',
#  'we',
#  'used',
#  'sentences',
#  'in',
#  'this',
#  'section',
#  'as',
#  'the',
#  'candidate',
#  'answers',
#  '.',
#  'with',
#  'the',
#  'help',
#  'of',
#  'crowdsourcing',
#  ',',
#  'we',
#  'included',
#  '3,047',
#  'questions',
#  'and',
#  '29,258',
#  'sentences',
#  'in',
#  'the',
#  'dataset',
#  ',',
#  'where',
#  '1,473',
#  'sentences',
#  'were',
#  'labeled',
#  'as',
#  'answer',
#  'sentences',
#  'to',
#  'their',
#  'corresponding',
#  'questions',
#  '.',
#  'more',
#  'detail',
#  'of',
#  'this',
#  'corpus',
#  'can',
#  'be',
#  'found',
#  'in',
#  'our',
#  'emnlp-2015',
#  'paper',
#  ',',
#  '``',
#  'wikiqa',
#  ':',
#  'a',
#  'challenge',
#  'dataset',
#  'for',
#  'open-domain',
#  'question',
#  'answering',
#  "''",
#  '[',
#  'yang',
#  'et',
#  'al',
#  '.',
#  '2015',
#  ']',
#  '.',
#  'in',
#  'addition',
#  ',',
#  'this',
#  'download',
#  'also',
#  'includes',
#  'the',
#  'experimental',
#  'results',
#  'in',
#  'the',
#  'paper',
#  ',',
#  'an',
#  'evaluation',
#  'script',
#  'for',
#  'judging',
#  'the',
#  '``',
#  'answer',
#  'triggering',
#  "''",
#  'task',
#  ',',
#  'as',
#  'well',
#  'as',
#  'the',
#  'answer',
#  'phrases',
#  'labeled',
#  'by',
#  'the',
#  'authors',
#  'of',
#  'the',
#  'paper',
#  '.']

# %% [markdown]
# # Number Removal

# %%
input_string = ' '.join(sr_list)

# %%
re.sub(r'\d+', ' ',input_string)
# Out:
# "wikiqa corpus new publicly available set question sentence pairs , collected annotated research open-domain question answering . order reflect true information need general users , used bing query logs question source . question linked wikipedia page potentially answer . summary section wikipedia page provides basic usually important information topic , used sentences section candidate answers . help crowdsourcing , included  ,  questions  ,  sentences dataset ,  ,  sentences labeled answer sentences corresponding questions . detail corpus found emnlp-  paper , `` wikiqa : challenge dataset open-domain question answering '' [ yang et al .   ] . addition , download also includes experimental results paper , evaluation script judging `` answer triggering '' task , well answer phrases labeled authors paper ."

# %% [markdown]
# # Spl Char Removal % Punctations

# %%
std_tokens = ['the',
 'wikiqa',
 'corpus',
 'is',
 'a',
 'new',
 'publicly',
 'available',
 'set',
 'of',
 'question',
 'and',
 'sentence',
 'pairs',
 ',',
 'collected',
 'and',
 'annotated',
 'for',
 'research',
 'on',
 'open-domain',
 'question',
 'answering',
 '.',
 'in',
 'order',
 'to',
 'reflect',
 'the',
 'true',
 'information',
 'need',
 'of',
 'general',
 'users',
 ',',
 'we',
 'used',
 'bing',
 'query',
 'logs',
 'as',
 'the',
 'question',
 'source',
 '.',
 'each',
 'question',
 'is',
 'linked',
 'to',
 'a',
 'wikipedia',
 'page',
 'that',
 'potentially',
 'has',
 'the',
 'answer',
 '.',
 'because',
 'the',
 'summary',
 'section',
 'of',
 'a',
 'wikipedia',
 'page',
 'provides',
 'the',
 'basic',
 'and',
 'usually',
 'most',
 'important',
 'information',
 'about',
 'the',
 'topic',
 ',',
 'we',
 'used',
 'sentences',
 'in',
 'this',
 'section',
 'as',
 'the',
 'candidate',
 'answers',
 '.',
 'with',
 'the',
 'help',
 'of',
 'crowdsourcing',
 ',',
 'we',
 'included',
 '3,047',
 'questions',
 'and',
 '29,258',
 'sentences',
 'in',
 'the',
 'dataset',
 ',',
 'where',
 '1,473',
 'sentences',
 'were',
 'labeled',
 'as',
 'answer',
 'sentences',
 'to',
 'their',
 'corresponding',
 'questions',
 '.',
 'more',
 'detail',
 'of',
 'this',
 'corpus',
 'can',
 'be',
 'found',
 'in',
 'our',
 'emnlp-2015',
 'paper',
 ',',
 '``',
 'wikiqa',
 ':',
 'a',
 'challenge',
 'dataset',
 'for',
 'open-domain',
 'question',
 'answering',
 "''",
 '[',
 'yang',
 'et',
 'al',
 '.',
 '2015',
 ']',
 '.',
 'in',
 'addition',
 ',',
 'this',
 'download',
 'also',
 'includes',
 'the',
 'experimental',
 'results',
 'in',
 'the',
 'paper',
 ',',
 'an',
 'evaluation',
 'script',
 'for',
 'judging',
 'the',
 '``',
 'answer',
 'triggering',
 "''",
 'task',
 ',',
 'as',
 'well',
 'as',
 'the',
 'answer',
 'phrases',
 'labeled',
 'by',
 'the',
 'authors',
 'of',
 'the',
 'paper',
 '.']

# %%
[re.sub(r'[^a-zA-Z0-9]', '', i )  for i in std_tokens]
# Out:
# ['the',
#  'wikiqa',
#  'corpus',
#  'is',
#  'a',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'of',
#  'question',
#  'and',
#  'sentence',
#  'pairs',
#  '',
#  'collected',
#  'and',
#  'annotated',
#  'for',
#  'research',
#  'on',
#  'opendomain',
#  'question',
#  'answering',
#  '',
#  'in',
#  'order',
#  'to',
#  'reflect',
#  'the',
#  'true',
#  'information',
#  'need',
#  'of',
#  'general',
#  'users',
#  '',
#  'we',
#  'used',
#  'bing',
#  'query',
#  'logs',
#  'as',
#  'the',
#  'question',
#  'source',
#  '',
#  'each',
#  'question',
#  'is',
#  'linked',
#  'to',
#  'a',
#  'wikipedia',
#  'page',
#  'that',
#  'potentially',
#  'has',
#  'the',
#  'answer',
#  '',
#  'because',
#  'the',
#  'summary',
#  'section',
#  'of',
#  'a',
#  'wikipedia',
#  'page',
#  'provides',
#  'the',
#  'basic',
#  'and',
#  'usually',
#  'most',
#  'important',
#  'information',
#  'about',
#  'the',
#  'topic',
#  '',
#  'we',
#  'used',
#  'sentences',
#  'in',
#  'this',
#  'section',
#  'as',
#  'the',
#  'candidate',
#  'answers',
#  '',
#  'with',
#  'the',
#  'help',
#  'of',
#  'crowdsourcing',
#  '',
#  'we',
#  'included',
#  '3047',
#  'questions',
#  'and',
#  '29258',
#  'sentences',
#  'in',
#  'the',
#  'dataset',
#  '',
#  'where',
#  '1473',
#  'sentences',
#  'were',
#  'labeled',
#  'as',
#  'answer',
#  'sentences',
#  'to',
#  'their',
#  'corresponding',
#  'questions',
#  '',
#  'more',
#  'detail',
#  'of',
#  'this',
#  'corpus',
#  'can',
#  'be',
#  'found',
#  'in',
#  'our',
#  'emnlp2015',
#  'paper',
#  '',
#  '',
#  'wikiqa',
#  '',
#  'a',
#  'challenge',
#  'dataset',
#  'for',
#  'opendomain',
#  'question',
#  'answering',
#  '',
#  '',
#  'yang',
#  'et',
#  'al',
#  '',
#  '2015',
#  '',
#  '',
#  'in',
#  'addition',
#  '',
#  'this',
#  'download',
#  'also',
#  'includes',
#  'the',
#  'experimental',
#  'results',
#  'in',
#  'the',
#  'paper',
#  '',
#  'an',
#  'evaluation',
#  'script',
#  'for',
#  'judging',
#  'the',
#  '',
#  'answer',
#  'triggering',
#  '',
#  'task',
#  '',
#  'as',
#  'well',
#  'as',
#  'the',
#  'answer',
#  'phrases',
#  'labeled',
#  'by',
#  'the',
#  'authors',
#  'of',
#  'the',
#  'paper',
#  '']

# %%
[re.sub(r'\w+', '', i )  for i in std_tokens]
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '-',
#  '',
#  '',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '-',
#  '',
#  ',',
#  '``',
#  '',
#  ':',
#  '',
#  '',
#  '',
#  '',
#  '-',
#  '',
#  '',
#  "''",
#  '[',
#  '',
#  '',
#  '',
#  '.',
#  '',
#  ']',
#  '.',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '``',
#  '',
#  '',
#  "''",
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '.']

# %% [markdown]
# # Spell checking

# %%
! pip install pyspellchecker
# Out:
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.7.2-py3-none-any.whl (3.4 MB)
#      ---------------------------------------- 0.0/3.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.4 MB 131.3 kB/s eta 0:00:26
#      ---------------------------------------- 0.0/3.4 MB 131.3 kB/s eta 0:00:26
#      ---------------------------------------- 0.0/3.4 MB 131.3 kB/s eta 0:00:26
#      ---------------------------------------- 0.0/3.4 MB 131.3 kB/s eta 0:00:26
#      ---------------------------------------- 0.0/3.4 MB 89.3 kB/s eta 0:00:38
#      ---------------------------------------- 0.0/3.4 MB 89.3 kB/s eta 0:00:38
#      ---------------------------------------- 0.0/3.4 MB 89.3 kB/s eta 0:00:38
#      ---------------------------------------- 0.0/3.4 MB 89.3 kB/s eta 0:00:38
#       --------------------------------------- 0.1/3.4 MB 93.6 kB/s eta 0:00:36
#       --------------------------------------- 0.1/3.4 MB 93.6 kB/s eta 0:00:36
#       --------------------------------------- 0.1/3.4 MB 100.9 kB/s eta 0:00:34
#       --------------------------------------- 0.1/3.4 MB 100.9 kB/s eta 0:00:34
#      - -------------------------------------- 0.1/3.4 MB 113.9 kB/s eta 0:00:30
#      - -------------------------------------- 0.1/3.4 MB 113.9 kB/s eta 0:00:30
#      - -------------------------------------- 0.1/3.4 MB 113.9 kB/s eta 0:00:30
#      - -------------------------------------- 0.1/3.4 MB 113.9 kB/s eta 0:00:30
#      - -------------------------------------- 0.1/3.4 MB 113.9 kB/s eta 0:00:30
#      - -------------------------------------- 0.1/3.4 MB 109.2 kB/s eta 0:00:31
#      - -------------------------------------- 0.1/3.4 MB 109.2 kB/s eta 0:00:31
#      - -------------------------------------- 0.1/3.4 MB 109.2 kB/s eta 0:00:31
#      - -------------------------------------- 0.1/3.4 MB 106.0 kB/s eta 0:00:32
#      - -------------------------------------- 0.1/3.4 MB 106.0 kB/s eta 0:00:32
#      - -------------------------------------- 0.1/3.4 MB 106.0 kB/s eta 0:00:32
#      - -------------------------------------- 0.1/3.4 MB 106.0 kB/s eta 0:00:32
#      - -------------------------------------- 0.1/3.4 MB 106.0 kB/s eta 0:00:32
#      - -------------------------------------- 0.1/3.4 MB 106.0 kB/s eta 0:00:32
#      - -------------------------------------- 0.1/3.4 MB 106.0 kB/s eta 0:00:32
#      - -------------------------------------- 0.1/3.4 MB 106.0 kB/s eta 0:00:32
#      - -------------------------------------- 0.1/3.4 MB 91.6 kB/s eta 0:00:36
#      - -------------------------------------- 0.1/3.4 MB 91.6 kB/s eta 0:00:36
#      - -------------------------------------- 0.1/3.4 MB 91.6 kB/s eta 0:00:36
#      - -------------------------------------- 0.1/3.4 MB 91.6 kB/s eta 0:00:36
#      - -------------------------------------- 0.1/3.4 MB 91.6 kB/s eta 0:00:36
#      - -------------------------------------- 0.1/3.4 MB 91.6 kB/s eta 0:00:36
#      - -------------------------------------- 0.1/3.4 MB 91.6 kB/s eta 0:00:36
#      - -------------------------------------- 0.1/3.4 MB 91.6 kB/s eta 0:00:36
#      - -------------------------------------- 0.2/3.4 MB 77.7 kB/s eta 0:00:43
#      - -------------------------------------- 0.2/3.4 MB 77.7 kB/s eta 0:00:43
#      - -------------------------------------- 0.2/3.4 MB 77.7 kB/s eta 0:00:43
#      - -------------------------------------- 0.2/3.4 MB 77.7 kB/s eta 0:00:43
#      - -------------------------------------- 0.2/3.4 MB 77.7 kB/s eta 0:00:43
#      - -------------------------------------- 0.2/3.4 MB 77.7 kB/s eta 0:00:43
#      - -------------------------------------- 0.2/3.4 MB 77.7 kB/s eta 0:00:43
#      - -------------------------------------- 0.2/3.4 MB 77.7 kB/s eta 0:00:43
#      - -------------------------------------- 0.2/3.4 MB 77.7 kB/s eta 0:00:43
#      - -------------------------------------- 0.2/3.4 MB 77.7 kB/s eta 0:00:43
#      -- ------------------------------------- 0.2/3.4 MB 69.9 kB/s eta 0:00:47
#      -- ------------------------------------- 0.2/3.4 MB 69.9 kB/s eta 0:00:47
#      -- ------------------------------------- 0.2/3.4 MB 69.9 kB/s eta 0:00:47
#      -- ------------------------------------- 0.2/3.4 MB 69.9 kB/s eta 0:00:47
#      -- ------------------------------------- 0.2/3.4 MB 69.9 kB/s eta 0:00:47
#      -- ------------------------------------- 0.2/3.4 MB 69.9 kB/s eta 0:00:47
#      -- ------------------------------------- 0.2/3.4 MB 69.8 kB/s eta 0:00:47
#      -- ------------------------------------- 0.2/3.4 MB 69.8 kB/s eta 0:00:47
#      -- ------------------------------------- 0.2/3.4 MB 69.8 kB/s eta 0:00:47
#      -- ------------------------------------- 0.2/3.4 MB 69.8 kB/s eta 0:00:47
#      -- ------------------------------------- 0.2/3.4 MB 69.8 kB/s eta 0:00:47
#      -- ------------------------------------- 0.2/3.4 MB 69.8 kB/s eta 0:00:47
#      -- ------------------------------------- 0.2/3.4 MB 69.8 kB/s eta 0:00:47
#      -- ------------------------------------- 0.2/3.4 MB 69.8 kB/s eta 0:00:47
#      -- ------------------------------------- 0.2/3.4 MB 69.8 kB/s eta 0:00:47
#      -- ------------------------------------- 0.2/3.4 MB 69.8 kB/s eta 0:00:47
#      -- ------------------------------------- 0.2/3.4 MB 69.8 kB/s eta 0:00:47
#      -- ------------------------------------- 0.2/3.4 MB 69.8 kB/s eta 0:00:47
#      -- ------------------------------------- 0.2/3.4 MB 69.8 kB/s eta 0:00:47
#      -- ------------------------------------- 0.2/3.4 MB 60.4 kB/s eta 0:00:54
#      -- ------------------------------------- 0.2/3.4 MB 60.4 kB/s eta 0:00:54
#      -- ------------------------------------- 0.2/3.4 MB 60.4 kB/s eta 0:00:54
#      -- ------------------------------------- 0.2/3.4 MB 60.4 kB/s eta 0:00:54
#      -- ------------------------------------- 0.2/3.4 MB 60.4 kB/s eta 0:00:54
#      -- ------------------------------------- 0.2/3.4 MB 60.4 kB/s eta 0:00:54
#      -- ------------------------------------- 0.2/3.4 MB 60.4 kB/s eta 0:00:54
#      -- ------------------------------------- 0.2/3.4 MB 60.4 kB/s eta 0:00:54
#      -- ------------------------------------- 0.2/3.4 MB 60.4 kB/s eta 0:00:54
#      -- ------------------------------------- 0.2/3.4 MB 59.3 kB/s eta 0:00:54
#      -- ------------------------------------- 0.2/3.4 MB 59.3 kB/s eta 0:00:54
#      -- ------------------------------------- 0.2/3.4 MB 59.3 kB/s eta 0:00:54
#      -- ------------------------------------- 0.2/3.4 MB 59.3 kB/s eta 0:00:54
#      -- ------------------------------------- 0.2/3.4 MB 59.3 kB/s eta 0:00:54
#      -- ------------------------------------- 0.2/3.4 MB 58.1 kB/s eta 0:00:55
#      -- ------------------------------------- 0.2/3.4 MB 58.1 kB/s eta 0:00:55
#      -- ------------------------------------- 0.2/3.4 MB 58.1 kB/s eta 0:00:55
#      -- ------------------------------------- 0.2/3.4 MB 58.1 kB/s eta 0:00:55
#      -- ------------------------------------- 0.2/3.4 MB 58.1 kB/s eta 0:00:55
#      -- ------------------------------------- 0.2/3.4 MB 58.1 kB/s eta 0:00:55
#      -- ------------------------------------- 0.3/3.4 MB 59.3 kB/s eta 0:00:54
#      -- ------------------------------------- 0.3/3.4 MB 59.3 kB/s eta 0:00:54
#      -- ------------------------------------- 0.3/3.4 MB 59.3 kB/s eta 0:00:54
#      -- ------------------------------------- 0.3/3.4 MB 59.3 kB/s eta 0:00:54
#      -- ------------------------------------- 0.3/3.4 MB 59.3 kB/s eta 0:00:54
#      --- ------------------------------------ 0.3/3.4 MB 60.9 kB/s eta 0:00:52
#      --- ------------------------------------ 0.3/3.4 MB 60.9 kB/s eta 0:00:52
#      --- ------------------------------------ 0.3/3.4 MB 60.9 kB/s eta 0:00:52
#      --- ------------------------------------ 0.3/3.4 MB 60.9 kB/s eta 0:00:52
#      --- ------------------------------------ 0.3/3.4 MB 60.9 kB/s eta 0:00:52
#      --- ------------------------------------ 0.3/3.4 MB 60.9 kB/s eta 0:00:52
#      --- ------------------------------------ 0.3/3.4 MB 59.6 kB/s eta 0:00:53
#      --- ------------------------------------ 0.3/3.4 MB 59.6 kB/s eta 0:00:53
#      --- ------------------------------------ 0.3/3.4 MB 59.6 kB/s eta 0:00:53
#      --- ------------------------------------ 0.3/3.4 MB 59.6 kB/s eta 0:00:53
#      --- ------------------------------------ 0.3/3.4 MB 59.6 kB/s eta 0:00:53
#      --- ------------------------------------ 0.3/3.4 MB 59.6 kB/s eta 0:00:53
#      --- ------------------------------------ 0.3/3.4 MB 59.6 kB/s eta 0:00:53
#      --- ------------------------------------ 0.3/3.4 MB 59.6 kB/s eta 0:00:53
#      --- ------------------------------------ 0.3/3.4 MB 59.6 kB/s eta 0:00:53
#      --- ------------------------------------ 0.3/3.4 MB 56.3 kB/s eta 0:00:56
#      --- ------------------------------------ 0.3/3.4 MB 58.1 kB/s eta 0:00:54
#      --- ------------------------------------ 0.3/3.4 MB 58.1 kB/s eta 0:00:54
#      --- ------------------------------------ 0.3/3.4 MB 58.1 kB/s eta 0:00:54
#      --- ------------------------------------ 0.3/3.4 MB 58.1 kB/s eta 0:00:54
#      --- ------------------------------------ 0.3/3.4 MB 58.1 kB/s eta 0:00:54
#      --- ------------------------------------ 0.3/3.4 MB 58.1 kB/s eta 0:00:54
#      --- ------------------------------------ 0.3/3.4 MB 56.7 kB/s eta 0:00:55
#      --- ------------------------------------ 0.3/3.4 MB 56.7 kB/s eta 0:00:55
#      --- ------------------------------------ 0.3/3.4 MB 56.7 kB/s eta 0:00:55
#      --- ------------------------------------ 0.3/3.4 MB 56.7 kB/s eta 0:00:55
#      --- ------------------------------------ 0.3/3.4 MB 56.7 kB/s eta 0:00:55
#      --- ------------------------------------ 0.3/3.4 MB 56.7 kB/s eta 0:00:55
#      --- ------------------------------------ 0.3/3.4 MB 57.8 kB/s eta 0:00:54
#      --- ------------------------------------ 0.3/3.4 MB 57.8 kB/s eta 0:00:54
#      --- ------------------------------------ 0.3/3.4 MB 57.8 kB/s eta 0:00:54
#      --- ------------------------------------ 0.3/3.4 MB 57.8 kB/s eta 0:00:54
#      --- ------------------------------------ 0.3/3.4 MB 57.8 kB/s eta 0:00:54
#      --- ------------------------------------ 0.3/3.4 MB 57.8 kB/s eta 0:00:54
#      --- ------------------------------------ 0.3/3.4 MB 57.8 kB/s eta 0:00:54
#      ---- ----------------------------------- 0.4/3.4 MB 58.0 kB/s eta 0:00:53
#      ---- ----------------------------------- 0.4/3.4 MB 58.0 kB/s eta 0:00:53
#      ---- ----------------------------------- 0.4/3.4 MB 58.0 kB/s eta 0:00:53
#      ---- ----------------------------------- 0.4/3.4 MB 58.0 kB/s eta 0:00:53
#      ---- ----------------------------------- 0.4/3.4 MB 58.0 kB/s eta 0:00:53
#      ---- ----------------------------------- 0.4/3.4 MB 58.0 kB/s eta 0:00:53
#      ---- ----------------------------------- 0.4/3.4 MB 57.2 kB/s eta 0:00:54
#      ---- ----------------------------------- 0.4/3.4 MB 57.2 kB/s eta 0:00:54
#      ---- ----------------------------------- 0.4/3.4 MB 57.2 kB/s eta 0:00:54
#      ---- ----------------------------------- 0.4/3.4 MB 57.2 kB/s eta 0:00:54
#      ---- ----------------------------------- 0.4/3.4 MB 57.2 kB/s eta 0:00:54
#      ---- ----------------------------------- 0.4/3.4 MB 58.1 kB/s eta 0:00:53
#      ---- ----------------------------------- 0.4/3.4 MB 58.1 kB/s eta 0:00:53
#      ---- ----------------------------------- 0.4/3.4 MB 58.7 kB/s eta 0:00:52
#      ---- ----------------------------------- 0.4/3.4 MB 58.7 kB/s eta 0:00:52
#      ---- ----------------------------------- 0.4/3.4 MB 58.7 kB/s eta 0:00:52
#      ---- ----------------------------------- 0.4/3.4 MB 58.7 kB/s eta 0:00:52
#      ---- ----------------------------------- 0.4/3.4 MB 58.7 kB/s eta 0:00:52
#      ---- ----------------------------------- 0.4/3.4 MB 58.7 kB/s eta 0:00:52
#      ---- ----------------------------------- 0.4/3.4 MB 58.7 kB/s eta 0:00:52
#      ---- ----------------------------------- 0.4/3.4 MB 58.7 kB/s eta 0:00:52
#      ---- ----------------------------------- 0.4/3.4 MB 58.7 kB/s eta 0:00:52
#      ---- ----------------------------------- 0.4/3.4 MB 58.7 kB/s eta 0:00:52
#      ---- ----------------------------------- 0.4/3.4 MB 58.7 kB/s eta 0:00:52
#      ---- ----------------------------------- 0.4/3.4 MB 58.7 kB/s eta 0:00:52
#      ---- ----------------------------------- 0.4/3.4 MB 58.7 kB/s eta 0:00:52
#      ---- ----------------------------------- 0.4/3.4 MB 58.7 kB/s eta 0:00:52
#      ---- ----------------------------------- 0.4/3.4 MB 58.7 kB/s eta 0:00:52
#      ---- ----------------------------------- 0.4/3.4 MB 58.7 kB/s eta 0:00:52
#      ---- ----------------------------------- 0.4/3.4 MB 58.7 kB/s eta 0:00:52
#      ---- ----------------------------------- 0.4/3.4 MB 58.7 kB/s eta 0:00:52
#      ---- ----------------------------------- 0.4/3.4 MB 58.7 kB/s eta 0:00:52
#      ----- ---------------------------------- 0.5/3.4 MB 62.8 kB/s eta 0:00:47
#      ----- ---------------------------------- 0.5/3.4 MB 63.8 kB/s eta 0:00:46
#      ----- ---------------------------------- 0.5/3.4 MB 63.8 kB/s eta 0:00:46
#      ----- ---------------------------------- 0.5/3.4 MB 63.8 kB/s eta 0:00:46
#      ----- ---------------------------------- 0.5/3.4 MB 63.8 kB/s eta 0:00:46
#      ----- ---------------------------------- 0.5/3.4 MB 63.8 kB/s eta 0:00:46
#      ----- ---------------------------------- 0.5/3.4 MB 63.8 kB/s eta 0:00:46
#      ----- ---------------------------------- 0.5/3.4 MB 63.8 kB/s eta 0:00:46
#      ----- ---------------------------------- 0.5/3.4 MB 63.8 kB/s eta 0:00:46
#      ----- ---------------------------------- 0.5/3.4 MB 63.8 kB/s eta 0:00:46
#      ----- ---------------------------------- 0.5/3.4 MB 63.8 kB/s eta 0:00:46
#      ----- ---------------------------------- 0.5/3.4 MB 63.8 kB/s eta 0:00:46
#      ----- ---------------------------------- 0.5/3.4 MB 63.8 kB/s eta 0:00:46
#      ----- ---------------------------------- 0.5/3.4 MB 63.8 kB/s eta 0:00:46
#      ----- ---------------------------------- 0.5/3.4 MB 63.8 kB/s eta 0:00:46
#      ----- ---------------------------------- 0.5/3.4 MB 63.8 kB/s eta 0:00:46
#      ----- ---------------------------------- 0.5/3.4 MB 63.8 kB/s eta 0:00:46
#      ----- ---------------------------------- 0.5/3.4 MB 63.8 kB/s eta 0:00:46
#      ----- ---------------------------------- 0.5/3.4 MB 63.8 kB/s eta 0:00:46
#      ----- ---------------------------------- 0.5/3.4 MB 63.8 kB/s eta 0:00:46
#      ----- ---------------------------------- 0.5/3.4 MB 63.8 kB/s eta 0:00:46
#      ----- ---------------------------------- 0.5/3.4 MB 59.4 kB/s eta 0:00:50
#      ----- ---------------------------------- 0.5/3.4 MB 59.4 kB/s eta 0:00:50
#      ----- ---------------------------------- 0.5/3.4 MB 59.4 kB/s eta 0:00:50
#      ----- ---------------------------------- 0.5/3.4 MB 59.4 kB/s eta 0:00:50
#      ----- ---------------------------------- 0.5/3.4 MB 59.4 kB/s eta 0:00:50
#      ----- ---------------------------------- 0.5/3.4 MB 59.4 kB/s eta 0:00:50
#      ----- ---------------------------------- 0.5/3.4 MB 59.4 kB/s eta 0:00:50
#      ----- ---------------------------------- 0.5/3.4 MB 59.4 kB/s eta 0:00:50
#      ----- ---------------------------------- 0.5/3.4 MB 59.4 kB/s eta 0:00:50
#      ----- ---------------------------------- 0.5/3.4 MB 59.4 kB/s eta 0:00:50
#      ----- ---------------------------------- 0.5/3.4 MB 59.4 kB/s eta 0:00:50
#      ----- ---------------------------------- 0.5/3.4 MB 59.4 kB/s eta 0:00:50
#      ----- ---------------------------------- 0.5/3.4 MB 59.4 kB/s eta 0:00:50
#      ----- ---------------------------------- 0.5/3.4 MB 59.4 kB/s eta 0:00:50
#      ------ --------------------------------- 0.5/3.4 MB 57.2 kB/s eta 0:00:51
#      ------ --------------------------------- 0.5/3.4 MB 57.2 kB/s eta 0:00:51
#      ------ --------------------------------- 0.5/3.4 MB 57.2 kB/s eta 0:00:51
#      ------ --------------------------------- 0.5/3.4 MB 57.2 kB/s eta 0:00:51
#      ------ --------------------------------- 0.5/3.4 MB 57.2 kB/s eta 0:00:51
#      ------ --------------------------------- 0.5/3.4 MB 57.2 kB/s eta 0:00:51
#      ------ --------------------------------- 0.5/3.4 MB 57.2 kB/s eta 0:00:51
#      ------ --------------------------------- 0.5/3.4 MB 56.4 kB/s eta 0:00:52
#      ------ --------------------------------- 0.5/3.4 MB 56.4 kB/s eta 0:00:52
#      ------ --------------------------------- 0.5/3.4 MB 56.4 kB/s eta 0:00:52
#      ------ --------------------------------- 0.5/3.4 MB 56.4 kB/s eta 0:00:52
#      ------ --------------------------------- 0.5/3.4 MB 56.4 kB/s eta 0:00:52
#      ------ --------------------------------- 0.5/3.4 MB 56.4 kB/s eta 0:00:52
#      ------ --------------------------------- 0.6/3.4 MB 57.0 kB/s eta 0:00:51
#      ------ --------------------------------- 0.6/3.4 MB 57.0 kB/s eta 0:00:51
#      ------ --------------------------------- 0.6/3.4 MB 57.0 kB/s eta 0:00:51
#      ------ --------------------------------- 0.6/3.4 MB 57.0 kB/s eta 0:00:51
#      ------ --------------------------------- 0.6/3.4 MB 57.0 kB/s eta 0:00:51
#      ------ --------------------------------- 0.6/3.4 MB 57.0 kB/s eta 0:00:51
#      ------ --------------------------------- 0.6/3.4 MB 56.3 kB/s eta 0:00:51
#      ------ --------------------------------- 0.6/3.4 MB 56.3 kB/s eta 0:00:51
#      ------ --------------------------------- 0.6/3.4 MB 56.3 kB/s eta 0:00:51
#      ------ --------------------------------- 0.6/3.4 MB 56.3 kB/s eta 0:00:51
#      ------ --------------------------------- 0.6/3.4 MB 56.3 kB/s eta 0:00:51
#      ------ --------------------------------- 0.6/3.4 MB 56.3 kB/s eta 0:00:51
#      ------ --------------------------------- 0.6/3.4 MB 56.9 kB/s eta 0:00:50
#      ------ --------------------------------- 0.6/3.4 MB 56.9 kB/s eta 0:00:50
#      ------ --------------------------------- 0.6/3.4 MB 56.9 kB/s eta 0:00:50
#      ------ --------------------------------- 0.6/3.4 MB 56.9 kB/s eta 0:00:50
#      ------ --------------------------------- 0.6/3.4 MB 56.9 kB/s eta 0:00:50
#      ------- -------------------------------- 0.6/3.4 MB 57.6 kB/s eta 0:00:49
#      ------- -------------------------------- 0.6/3.4 MB 57.6 kB/s eta 0:00:49
#      ------- -------------------------------- 0.6/3.4 MB 57.6 kB/s eta 0:00:49
#      ------- -------------------------------- 0.6/3.4 MB 57.6 kB/s eta 0:00:49
#      ------- -------------------------------- 0.6/3.4 MB 57.6 kB/s eta 0:00:49
#      ------- -------------------------------- 0.6/3.4 MB 57.3 kB/s eta 0:00:49
#      ------- -------------------------------- 0.6/3.4 MB 57.3 kB/s eta 0:00:49
#      ------- -------------------------------- 0.6/3.4 MB 57.3 kB/s eta 0:00:49
#      ------- -------------------------------- 0.6/3.4 MB 57.3 kB/s eta 0:00:49
#      ------- -------------------------------- 0.6/3.4 MB 57.3 kB/s eta 0:00:49
#      ------- -------------------------------- 0.6/3.4 MB 57.3 kB/s eta 0:00:49
#      ------- -------------------------------- 0.6/3.4 MB 57.3 kB/s eta 0:00:49
#      ------- -------------------------------- 0.6/3.4 MB 57.4 kB/s eta 0:00:49
#      ------- -------------------------------- 0.6/3.4 MB 57.4 kB/s eta 0:00:49
#      ------- -------------------------------- 0.6/3.4 MB 57.4 kB/s eta 0:00:49
#      ------- -------------------------------- 0.6/3.4 MB 57.4 kB/s eta 0:00:49
#      ------- -------------------------------- 0.6/3.4 MB 57.4 kB/s eta 0:00:49
#      ------- -------------------------------- 0.7/3.4 MB 57.1 kB/s eta 0:00:49
#      ------- -------------------------------- 0.7/3.4 MB 57.1 kB/s eta 0:00:49
#      ------- -------------------------------- 0.7/3.4 MB 57.1 kB/s eta 0:00:49
#      ------- -------------------------------- 0.7/3.4 MB 57.1 kB/s eta 0:00:49
#      ------- -------------------------------- 0.7/3.4 MB 57.1 kB/s eta 0:00:49
#      ------- -------------------------------- 0.7/3.4 MB 57.1 kB/s eta 0:00:49
#      ------- -------------------------------- 0.7/3.4 MB 57.6 kB/s eta 0:00:48
#      ------- -------------------------------- 0.7/3.4 MB 57.6 kB/s eta 0:00:48
#      ------- -------------------------------- 0.7/3.4 MB 57.6 kB/s eta 0:00:48
#      ------- -------------------------------- 0.7/3.4 MB 57.6 kB/s eta 0:00:48
#      ------- -------------------------------- 0.7/3.4 MB 57.6 kB/s eta 0:00:48
#      ------- -------------------------------- 0.7/3.4 MB 57.6 kB/s eta 0:00:48
#      ------- -------------------------------- 0.7/3.4 MB 57.6 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 57.8 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 57.8 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 57.8 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 57.8 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 57.8 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 57.8 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 57.8 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 57.8 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 57.8 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 56.6 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 56.6 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 56.6 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 56.6 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 56.6 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 56.6 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 56.6 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 56.7 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 56.7 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 56.7 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 56.7 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 56.7 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 56.7 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 56.3 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 56.3 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 56.3 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 56.3 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 56.3 kB/s eta 0:00:48
#      -------- ------------------------------- 0.7/3.4 MB 56.3 kB/s eta 0:00:48
#      -------- ------------------------------- 0.8/3.4 MB 56.7 kB/s eta 0:00:48
#      -------- ------------------------------- 0.8/3.4 MB 56.7 kB/s eta 0:00:48
#      -------- ------------------------------- 0.8/3.4 MB 56.7 kB/s eta 0:00:48
#      -------- ------------------------------- 0.8/3.4 MB 56.7 kB/s eta 0:00:48
#      -------- ------------------------------- 0.8/3.4 MB 56.7 kB/s eta 0:00:48
#      -------- ------------------------------- 0.8/3.4 MB 56.7 kB/s eta 0:00:48
#      --------- ------------------------------ 0.8/3.4 MB 57.0 kB/s eta 0:00:47
#      --------- ------------------------------ 0.8/3.4 MB 57.0 kB/s eta 0:00:47
#      --------- ------------------------------ 0.8/3.4 MB 57.0 kB/s eta 0:00:47
#      --------- ------------------------------ 0.8/3.4 MB 57.0 kB/s eta 0:00:47
#      --------- ------------------------------ 0.8/3.4 MB 57.0 kB/s eta 0:00:47
#      --------- ------------------------------ 0.8/3.4 MB 57.0 kB/s eta 0:00:47
#      --------- ------------------------------ 0.8/3.4 MB 56.7 kB/s eta 0:00:47
#      --------- ------------------------------ 0.8/3.4 MB 56.7 kB/s eta 0:00:47
#      --------- ------------------------------ 0.8/3.4 MB 56.7 kB/s eta 0:00:47
#      --------- ------------------------------ 0.8/3.4 MB 56.7 kB/s eta 0:00:47
#      --------- ------------------------------ 0.8/3.4 MB 56.7 kB/s eta 0:00:47
#      --------- ------------------------------ 0.8/3.4 MB 56.7 kB/s eta 0:00:47
#      --------- ------------------------------ 0.8/3.4 MB 57.0 kB/s eta 0:00:46
#      --------- ------------------------------ 0.8/3.4 MB 57.0 kB/s eta 0:00:46
#      --------- ------------------------------ 0.8/3.4 MB 57.0 kB/s eta 0:00:46
#      --------- ------------------------------ 0.8/3.4 MB 57.0 kB/s eta 0:00:46
#      --------- ------------------------------ 0.8/3.4 MB 56.9 kB/s eta 0:00:46
#      --------- ------------------------------ 0.8/3.4 MB 56.9 kB/s eta 0:00:46
#      --------- ------------------------------ 0.8/3.4 MB 56.9 kB/s eta 0:00:46
#      --------- ------------------------------ 0.8/3.4 MB 56.9 kB/s eta 0:00:46
#      --------- ------------------------------ 0.8/3.4 MB 56.9 kB/s eta 0:00:46
#      --------- ------------------------------ 0.8/3.4 MB 57.4 kB/s eta 0:00:45
#      --------- ------------------------------ 0.8/3.4 MB 57.4 kB/s eta 0:00:45
#      --------- ------------------------------ 0.8/3.4 MB 57.4 kB/s eta 0:00:45
#      --------- ------------------------------ 0.8/3.4 MB 57.4 kB/s eta 0:00:45
#      ---------- ----------------------------- 0.9/3.4 MB 58.1 kB/s eta 0:00:45
#      ---------- ----------------------------- 0.9/3.4 MB 58.1 kB/s eta 0:00:45
#      ---------- ----------------------------- 0.9/3.4 MB 58.1 kB/s eta 0:00:45
#      ---------- ----------------------------- 0.9/3.4 MB 58.2 kB/s eta 0:00:44
#      ---------- ----------------------------- 0.9/3.4 MB 58.2 kB/s eta 0:00:44
#      ---------- ----------------------------- 0.9/3.4 MB 58.2 kB/s eta 0:00:44
#      ---------- ----------------------------- 0.9/3.4 MB 58.2 kB/s eta 0:00:44
#      ---------- ----------------------------- 0.9/3.4 MB 59.0 kB/s eta 0:00:43
#      ---------- ----------------------------- 0.9/3.4 MB 59.0 kB/s eta 0:00:43
#      ---------- ----------------------------- 0.9/3.4 MB 59.1 kB/s eta 0:00:43
#      ---------- ----------------------------- 0.9/3.4 MB 59.1 kB/s eta 0:00:43
#      ---------- ----------------------------- 0.9/3.4 MB 59.1 kB/s eta 0:00:43
#      ---------- ----------------------------- 0.9/3.4 MB 60.0 kB/s eta 0:00:42
#      ---------- ----------------------------- 0.9/3.4 MB 60.0 kB/s eta 0:00:42
#      ---------- ----------------------------- 0.9/3.4 MB 60.0 kB/s eta 0:00:42
#      ---------- ----------------------------- 0.9/3.4 MB 60.0 kB/s eta 0:00:42
#      ---------- ----------------------------- 0.9/3.4 MB 60.0 kB/s eta 0:00:42
#      ----------- ---------------------------- 0.9/3.4 MB 60.4 kB/s eta 0:00:42
#      ----------- ---------------------------- 0.9/3.4 MB 60.4 kB/s eta 0:00:42
#      ----------- ---------------------------- 0.9/3.4 MB 60.4 kB/s eta 0:00:42
#      ----------- ---------------------------- 0.9/3.4 MB 60.4 kB/s eta 0:00:42
#      ----------- ---------------------------- 0.9/3.4 MB 60.4 kB/s eta 0:00:42
#      ----------- ---------------------------- 1.0/3.4 MB 60.2 kB/s eta 0:00:42
#      ----------- ---------------------------- 1.0/3.4 MB 60.2 kB/s eta 0:00:42
#      ----------- ---------------------------- 1.0/3.4 MB 60.2 kB/s eta 0:00:42
#      ----------- ---------------------------- 1.0/3.4 MB 60.2 kB/s eta 0:00:42
#      ----------- ---------------------------- 1.0/3.4 MB 60.2 kB/s eta 0:00:42
#      ----------- ---------------------------- 1.0/3.4 MB 60.5 kB/s eta 0:00:41
#      ----------- ---------------------------- 1.0/3.4 MB 60.5 kB/s eta 0:00:41
#      ----------- ---------------------------- 1.0/3.4 MB 60.5 kB/s eta 0:00:41
#      ----------- ---------------------------- 1.0/3.4 MB 60.7 kB/s eta 0:00:41
#      ----------- ---------------------------- 1.0/3.4 MB 60.7 kB/s eta 0:00:41
#      ----------- ---------------------------- 1.0/3.4 MB 60.7 kB/s eta 0:00:41
#      ----------- ---------------------------- 1.0/3.4 MB 60.7 kB/s eta 0:00:41
#      ----------- ---------------------------- 1.0/3.4 MB 60.7 kB/s eta 0:00:41
#      ----------- ---------------------------- 1.0/3.4 MB 60.7 kB/s eta 0:00:41
#      ----------- ---------------------------- 1.0/3.4 MB 60.7 kB/s eta 0:00:41
#      ----------- ---------------------------- 1.0/3.4 MB 60.7 kB/s eta 0:00:41
#      ----------- ---------------------------- 1.0/3.4 MB 61.2 kB/s eta 0:00:40
#      ----------- ---------------------------- 1.0/3.4 MB 61.2 kB/s eta 0:00:40
#      ----------- ---------------------------- 1.0/3.4 MB 61.2 kB/s eta 0:00:40
#      ----------- ---------------------------- 1.0/3.4 MB 61.2 kB/s eta 0:00:40
#      ----------- ---------------------------- 1.0/3.4 MB 61.2 kB/s eta 0:00:40
#      ----------- ---------------------------- 1.0/3.4 MB 61.2 kB/s eta 0:00:40
#      ----------- ---------------------------- 1.0/3.4 MB 61.2 kB/s eta 0:00:40
#      ----------- ---------------------------- 1.0/3.4 MB 61.2 kB/s eta 0:00:40
#      ----------- ---------------------------- 1.0/3.4 MB 61.2 kB/s eta 0:00:40
#      ------------ --------------------------- 1.0/3.4 MB 60.9 kB/s eta 0:00:40
#      ------------ --------------------------- 1.0/3.4 MB 60.9 kB/s eta 0:00:40
#      ------------ --------------------------- 1.0/3.4 MB 60.9 kB/s eta 0:00:40
#      ------------ --------------------------- 1.0/3.4 MB 60.9 kB/s eta 0:00:40
#      ------------ --------------------------- 1.0/3.4 MB 60.8 kB/s eta 0:00:40
#      ------------ --------------------------- 1.0/3.4 MB 60.8 kB/s eta 0:00:40
#      ------------ --------------------------- 1.0/3.4 MB 60.8 kB/s eta 0:00:40
#      ------------ --------------------------- 1.0/3.4 MB 60.8 kB/s eta 0:00:40
#      ------------ --------------------------- 1.0/3.4 MB 60.8 kB/s eta 0:00:40
#      ------------ --------------------------- 1.0/3.4 MB 60.8 kB/s eta 0:00:40
#      ------------ --------------------------- 1.1/3.4 MB 61.0 kB/s eta 0:00:39
#      ------------ --------------------------- 1.1/3.4 MB 61.0 kB/s eta 0:00:39
#      ------------ --------------------------- 1.1/3.4 MB 61.0 kB/s eta 0:00:39
#      ------------ --------------------------- 1.1/3.4 MB 61.0 kB/s eta 0:00:39
#      ------------ --------------------------- 1.1/3.4 MB 60.9 kB/s eta 0:00:39
#      ------------ --------------------------- 1.1/3.4 MB 60.9 kB/s eta 0:00:39
#      ------------ --------------------------- 1.1/3.4 MB 60.9 kB/s eta 0:00:39
#      ------------ --------------------------- 1.1/3.4 MB 60.9 kB/s eta 0:00:39
#      ------------ --------------------------- 1.1/3.4 MB 60.9 kB/s eta 0:00:39
#      ------------ --------------------------- 1.1/3.4 MB 61.4 kB/s eta 0:00:38
#      ------------ --------------------------- 1.1/3.4 MB 61.4 kB/s eta 0:00:38
#      ------------ --------------------------- 1.1/3.4 MB 61.4 kB/s eta 0:00:38
#      ------------ --------------------------- 1.1/3.4 MB 61.3 kB/s eta 0:00:38
#      ------------ --------------------------- 1.1/3.4 MB 61.3 kB/s eta 0:00:38
#      ------------ --------------------------- 1.1/3.4 MB 61.3 kB/s eta 0:00:38
#      ------------ --------------------------- 1.1/3.4 MB 61.3 kB/s eta 0:00:38
#      ------------- -------------------------- 1.1/3.4 MB 61.8 kB/s eta 0:00:38
#      ------------- -------------------------- 1.1/3.4 MB 61.8 kB/s eta 0:00:38
#      ------------- -------------------------- 1.1/3.4 MB 61.8 kB/s eta 0:00:38
#      ------------- -------------------------- 1.1/3.4 MB 62.3 kB/s eta 0:00:37
#      ------------- -------------------------- 1.1/3.4 MB 62.3 kB/s eta 0:00:37
#      ------------- -------------------------- 1.1/3.4 MB 62.3 kB/s eta 0:00:37
#      ------------- -------------------------- 1.2/3.4 MB 62.4 kB/s eta 0:00:37
#      ------------- -------------------------- 1.2/3.4 MB 62.4 kB/s eta 0:00:37
#      ------------- -------------------------- 1.2/3.4 MB 62.4 kB/s eta 0:00:37
#      ------------- -------------------------- 1.2/3.4 MB 63.0 kB/s eta 0:00:36
#      ------------- -------------------------- 1.2/3.4 MB 63.0 kB/s eta 0:00:36
#      ------------- -------------------------- 1.2/3.4 MB 63.1 kB/s eta 0:00:36
#      ------------- -------------------------- 1.2/3.4 MB 63.1 kB/s eta 0:00:36
#      ------------- -------------------------- 1.2/3.4 MB 63.1 kB/s eta 0:00:36
#      ------------- -------------------------- 1.2/3.4 MB 63.1 kB/s eta 0:00:36
#      -------------- ------------------------- 1.2/3.4 MB 63.6 kB/s eta 0:00:35
#      -------------- ------------------------- 1.2/3.4 MB 63.6 kB/s eta 0:00:35
#      -------------- ------------------------- 1.2/3.4 MB 63.6 kB/s eta 0:00:35
#      -------------- ------------------------- 1.2/3.4 MB 63.6 kB/s eta 0:00:35
#      -------------- ------------------------- 1.2/3.4 MB 63.6 kB/s eta 0:00:35
#      -------------- ------------------------- 1.2/3.4 MB 63.6 kB/s eta 0:00:35
#      -------------- ------------------------- 1.2/3.4 MB 63.8 kB/s eta 0:00:35
#      -------------- ------------------------- 1.2/3.4 MB 63.8 kB/s eta 0:00:35
#      -------------- ------------------------- 1.2/3.4 MB 63.8 kB/s eta 0:00:35
#      -------------- ------------------------- 1.2/3.4 MB 63.8 kB/s eta 0:00:35
#      -------------- ------------------------- 1.2/3.4 MB 63.8 kB/s eta 0:00:35
#      -------------- ------------------------- 1.2/3.4 MB 63.8 kB/s eta 0:00:35
#      -------------- ------------------------- 1.2/3.4 MB 63.8 kB/s eta 0:00:35
#      -------------- ------------------------- 1.2/3.4 MB 63.8 kB/s eta 0:00:35
#      -------------- ------------------------- 1.2/3.4 MB 63.8 kB/s eta 0:00:35
#      -------------- ------------------------- 1.2/3.4 MB 62.9 kB/s eta 0:00:35
#      -------------- ------------------------- 1.2/3.4 MB 62.9 kB/s eta 0:00:35
#      -------------- ------------------------- 1.2/3.4 MB 62.9 kB/s eta 0:00:35
#      -------------- ------------------------- 1.2/3.4 MB 62.9 kB/s eta 0:00:35
#      -------------- ------------------------- 1.2/3.4 MB 62.9 kB/s eta 0:00:35
#      -------------- ------------------------- 1.2/3.4 MB 62.9 kB/s eta 0:00:35
#      -------------- ------------------------- 1.3/3.4 MB 63.0 kB/s eta 0:00:35
#      -------------- ------------------------- 1.3/3.4 MB 63.0 kB/s eta 0:00:35
#      -------------- ------------------------- 1.3/3.4 MB 63.0 kB/s eta 0:00:35
#      -------------- ------------------------- 1.3/3.4 MB 63.1 kB/s eta 0:00:35
#      -------------- ------------------------- 1.3/3.4 MB 63.1 kB/s eta 0:00:35
#      -------------- ------------------------- 1.3/3.4 MB 63.1 kB/s eta 0:00:35
#      -------------- ------------------------- 1.3/3.4 MB 63.1 kB/s eta 0:00:35
#      --------------- ------------------------ 1.3/3.4 MB 63.5 kB/s eta 0:00:34
#      --------------- ------------------------ 1.3/3.4 MB 63.5 kB/s eta 0:00:34
#      --------------- ------------------------ 1.3/3.4 MB 63.5 kB/s eta 0:00:34
#      --------------- ------------------------ 1.3/3.4 MB 64.1 kB/s eta 0:00:33
#      --------------- ------------------------ 1.3/3.4 MB 64.1 kB/s eta 0:00:33
#      --------------- ------------------------ 1.3/3.4 MB 64.2 kB/s eta 0:00:33
#      --------------- ------------------------ 1.3/3.4 MB 64.2 kB/s eta 0:00:33
#      --------------- ------------------------ 1.3/3.4 MB 64.2 kB/s eta 0:00:33
#      --------------- ------------------------ 1.3/3.4 MB 64.8 kB/s eta 0:00:33
#      --------------- ------------------------ 1.3/3.4 MB 64.8 kB/s eta 0:00:33
#      --------------- ------------------------ 1.4/3.4 MB 64.9 kB/s eta 0:00:32
#      --------------- ------------------------ 1.4/3.4 MB 64.9 kB/s eta 0:00:32
#      --------------- ------------------------ 1.4/3.4 MB 64.9 kB/s eta 0:00:32
#      ---------------- ----------------------- 1.4/3.4 MB 65.5 kB/s eta 0:00:32
#      ---------------- ----------------------- 1.4/3.4 MB 65.5 kB/s eta 0:00:32
#      ---------------- ----------------------- 1.4/3.4 MB 65.5 kB/s eta 0:00:32
#      ---------------- ----------------------- 1.4/3.4 MB 65.5 kB/s eta 0:00:32
#      ---------------- ----------------------- 1.4/3.4 MB 65.9 kB/s eta 0:00:31
#      ---------------- ----------------------- 1.4/3.4 MB 65.9 kB/s eta 0:00:31
#      ---------------- ----------------------- 1.4/3.4 MB 65.9 kB/s eta 0:00:31
#      ---------------- ----------------------- 1.4/3.4 MB 65.9 kB/s eta 0:00:31
#      ---------------- ----------------------- 1.4/3.4 MB 65.7 kB/s eta 0:00:31
#      ---------------- ----------------------- 1.4/3.4 MB 65.7 kB/s eta 0:00:31
#      ---------------- ----------------------- 1.4/3.4 MB 65.7 kB/s eta 0:00:31
#      ---------------- ----------------------- 1.4/3.4 MB 65.7 kB/s eta 0:00:31
#      ---------------- ----------------------- 1.4/3.4 MB 66.1 kB/s eta 0:00:31
#      ---------------- ----------------------- 1.4/3.4 MB 66.1 kB/s eta 0:00:31
#      ---------------- ----------------------- 1.4/3.4 MB 66.1 kB/s eta 0:00:31
#      ---------------- ----------------------- 1.4/3.4 MB 66.1 kB/s eta 0:00:31
#      ---------------- ----------------------- 1.4/3.4 MB 66.0 kB/s eta 0:00:31
#      ---------------- ----------------------- 1.4/3.4 MB 66.0 kB/s eta 0:00:31
#      ---------------- ----------------------- 1.4/3.4 MB 66.0 kB/s eta 0:00:31
#      ---------------- ----------------------- 1.4/3.4 MB 66.0 kB/s eta 0:00:31
#      ---------------- ----------------------- 1.4/3.4 MB 66.0 kB/s eta 0:00:31
#      ---------------- ----------------------- 1.4/3.4 MB 66.0 kB/s eta 0:00:31
#      ---------------- ----------------------- 1.4/3.4 MB 66.0 kB/s eta 0:00:31
#      ---------------- ----------------------- 1.5/3.4 MB 65.9 kB/s eta 0:00:30
#      ---------------- ----------------------- 1.5/3.4 MB 65.9 kB/s eta 0:00:30
#      ---------------- ----------------------- 1.5/3.4 MB 65.9 kB/s eta 0:00:30
#      ---------------- ----------------------- 1.5/3.4 MB 65.9 kB/s eta 0:00:30
#      ---------------- ----------------------- 1.5/3.4 MB 65.9 kB/s eta 0:00:30
#      ---------------- ----------------------- 1.5/3.4 MB 65.9 kB/s eta 0:00:30
#      ---------------- ----------------------- 1.5/3.4 MB 65.9 kB/s eta 0:00:30
#      ----------------- ---------------------- 1.5/3.4 MB 65.7 kB/s eta 0:00:30
#      ----------------- ---------------------- 1.5/3.4 MB 65.7 kB/s eta 0:00:30
#      ----------------- ---------------------- 1.5/3.4 MB 65.7 kB/s eta 0:00:30
#      ----------------- ---------------------- 1.5/3.4 MB 65.7 kB/s eta 0:00:30
#      ----------------- ---------------------- 1.5/3.4 MB 65.7 kB/s eta 0:00:30
#      ----------------- ---------------------- 1.5/3.4 MB 65.7 kB/s eta 0:00:30
#      ----------------- ---------------------- 1.5/3.4 MB 66.3 kB/s eta 0:00:29
#      ----------------- ---------------------- 1.5/3.4 MB 66.3 kB/s eta 0:00:29
#      ----------------- ---------------------- 1.5/3.4 MB 66.3 kB/s eta 0:00:29
#      ----------------- ---------------------- 1.5/3.4 MB 66.3 kB/s eta 0:00:29
#      ----------------- ---------------------- 1.5/3.4 MB 66.2 kB/s eta 0:00:29
#      ----------------- ---------------------- 1.5/3.4 MB 66.2 kB/s eta 0:00:29
#      ----------------- ---------------------- 1.5/3.4 MB 66.2 kB/s eta 0:00:29
#      ----------------- ---------------------- 1.5/3.4 MB 66.2 kB/s eta 0:00:29
#      ----------------- ---------------------- 1.5/3.4 MB 66.5 kB/s eta 0:00:29
#      ----------------- ---------------------- 1.5/3.4 MB 66.5 kB/s eta 0:00:29
#      ----------------- ---------------------- 1.5/3.4 MB 66.5 kB/s eta 0:00:29
#      ----------------- ---------------------- 1.5/3.4 MB 66.5 kB/s eta 0:00:29
#      ----------------- ---------------------- 1.5/3.4 MB 66.5 kB/s eta 0:00:29
#      ------------------ --------------------- 1.6/3.4 MB 66.8 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.8 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.9 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.9 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.9 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.9 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.9 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.9 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.9 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.9 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.9 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.9 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.9 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.9 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.9 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.9 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.3 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.3 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.3 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.3 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.3 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.3 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.5 kB/s eta 0:00:28
#      ------------------ --------------------- 1.6/3.4 MB 66.5 kB/s eta 0:00:28
#      ------------------- -------------------- 1.6/3.4 MB 67.0 kB/s eta 0:00:27
#      ------------------- -------------------- 1.6/3.4 MB 67.0 kB/s eta 0:00:27
#      ------------------- -------------------- 1.6/3.4 MB 67.0 kB/s eta 0:00:27
#      ------------------- -------------------- 1.6/3.4 MB 67.1 kB/s eta 0:00:27
#      ------------------- -------------------- 1.6/3.4 MB 67.1 kB/s eta 0:00:27
#      ------------------- -------------------- 1.6/3.4 MB 67.1 kB/s eta 0:00:27
#      ------------------- -------------------- 1.7/3.4 MB 67.5 kB/s eta 0:00:26
#      ------------------- -------------------- 1.7/3.4 MB 67.5 kB/s eta 0:00:26
#      ------------------- -------------------- 1.7/3.4 MB 67.5 kB/s eta 0:00:26
#      ------------------- -------------------- 1.7/3.4 MB 67.6 kB/s eta 0:00:26
#      ------------------- -------------------- 1.7/3.4 MB 67.6 kB/s eta 0:00:26
#      ------------------- -------------------- 1.7/3.4 MB 67.6 kB/s eta 0:00:26
#      ------------------- -------------------- 1.7/3.4 MB 67.6 kB/s eta 0:00:26
#      ------------------- -------------------- 1.7/3.4 MB 67.8 kB/s eta 0:00:26
#      ------------------- -------------------- 1.7/3.4 MB 67.8 kB/s eta 0:00:26
#      ------------------- -------------------- 1.7/3.4 MB 67.8 kB/s eta 0:00:26
#      -------------------- ------------------- 1.7/3.4 MB 68.3 kB/s eta 0:00:25
#      -------------------- ------------------- 1.7/3.4 MB 68.3 kB/s eta 0:00:25
#      -------------------- ------------------- 1.7/3.4 MB 68.3 kB/s eta 0:00:25
#      -------------------- ------------------- 1.7/3.4 MB 68.3 kB/s eta 0:00:25
#      -------------------- ------------------- 1.7/3.4 MB 68.3 kB/s eta 0:00:25
#      -------------------- ------------------- 1.7/3.4 MB 68.3 kB/s eta 0:00:25
#      -------------------- ------------------- 1.7/3.4 MB 68.3 kB/s eta 0:00:25
#      -------------------- ------------------- 1.7/3.4 MB 68.3 kB/s eta 0:00:25
#      -------------------- ------------------- 1.8/3.4 MB 68.3 kB/s eta 0:00:25
#      -------------------- ------------------- 1.8/3.4 MB 68.3 kB/s eta 0:00:25
#      -------------------- ------------------- 1.8/3.4 MB 68.3 kB/s eta 0:00:25
#      -------------------- ------------------- 1.8/3.4 MB 68.3 kB/s eta 0:00:25
#      -------------------- ------------------- 1.8/3.4 MB 68.3 kB/s eta 0:00:25
#      -------------------- ------------------- 1.8/3.4 MB 68.3 kB/s eta 0:00:25
#      -------------------- ------------------- 1.8/3.4 MB 68.3 kB/s eta 0:00:25
#      -------------------- ------------------- 1.8/3.4 MB 67.8 kB/s eta 0:00:25
#      -------------------- ------------------- 1.8/3.4 MB 67.8 kB/s eta 0:00:25
#      -------------------- ------------------- 1.8/3.4 MB 67.8 kB/s eta 0:00:25
#      -------------------- ------------------- 1.8/3.4 MB 67.8 kB/s eta 0:00:25
#      -------------------- ------------------- 1.8/3.4 MB 67.8 kB/s eta 0:00:25
#      -------------------- ------------------- 1.8/3.4 MB 67.8 kB/s eta 0:00:25
#      -------------------- ------------------- 1.8/3.4 MB 67.8 kB/s eta 0:00:25
#      -------------------- ------------------- 1.8/3.4 MB 67.8 kB/s eta 0:00:25
#      -------------------- ------------------- 1.8/3.4 MB 67.6 kB/s eta 0:00:25
#      -------------------- ------------------- 1.8/3.4 MB 67.6 kB/s eta 0:00:25
#      -------------------- ------------------- 1.8/3.4 MB 67.6 kB/s eta 0:00:25
#      --------------------- ------------------ 1.8/3.4 MB 68.1 kB/s eta 0:00:24
#      --------------------- ------------------ 1.8/3.4 MB 68.1 kB/s eta 0:00:24
#      --------------------- ------------------ 1.8/3.4 MB 68.2 kB/s eta 0:00:24
#      --------------------- ------------------ 1.8/3.4 MB 68.2 kB/s eta 0:00:24
#      --------------------- ------------------ 1.8/3.4 MB 68.2 kB/s eta 0:00:24
#      --------------------- ------------------ 1.8/3.4 MB 68.2 kB/s eta 0:00:24
#      --------------------- ------------------ 1.8/3.4 MB 68.5 kB/s eta 0:00:24
#      --------------------- ------------------ 1.8/3.4 MB 68.5 kB/s eta 0:00:24
#      --------------------- ------------------ 1.8/3.4 MB 68.5 kB/s eta 0:00:24
#      --------------------- ------------------ 1.8/3.4 MB 68.5 kB/s eta 0:00:24
#      --------------------- ------------------ 1.8/3.4 MB 68.4 kB/s eta 0:00:24
#      --------------------- ------------------ 1.8/3.4 MB 68.4 kB/s eta 0:00:24
#      --------------------- ------------------ 1.8/3.4 MB 68.4 kB/s eta 0:00:24
#      --------------------- ------------------ 1.8/3.4 MB 68.4 kB/s eta 0:00:24
#      --------------------- ------------------ 1.9/3.4 MB 68.7 kB/s eta 0:00:23
#      --------------------- ------------------ 1.9/3.4 MB 68.7 kB/s eta 0:00:23
#      --------------------- ------------------ 1.9/3.4 MB 68.7 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 69.1 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 69.1 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 69.1 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 69.1 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 69.1 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 69.1 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 68.6 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 68.6 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 68.6 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 68.6 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 68.6 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 68.6 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 68.6 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 68.6 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 68.6 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 68.6 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 68.6 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 68.6 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 68.6 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 68.6 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 68.6 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 68.6 kB/s eta 0:00:23
#      ---------------------- ----------------- 1.9/3.4 MB 68.6 kB/s eta 0:00:22
#      ---------------------- ----------------- 1.9/3.4 MB 68.6 kB/s eta 0:00:22
#      ---------------------- ----------------- 2.0/3.4 MB 68.8 kB/s eta 0:00:22
#      ---------------------- ----------------- 2.0/3.4 MB 68.8 kB/s eta 0:00:22
#      ---------------------- ----------------- 2.0/3.4 MB 68.8 kB/s eta 0:00:22
#      ----------------------- ---------------- 2.0/3.4 MB 69.1 kB/s eta 0:00:21
#      ----------------------- ---------------- 2.0/3.4 MB 69.1 kB/s eta 0:00:21
#      ----------------------- ---------------- 2.0/3.4 MB 69.1 kB/s eta 0:00:21
# ...
#      ----------------------------- ---------- 2.5/3.4 MB 75.6 kB/s eta 0:00:12
#      ----------------------------- ---------- 2.5/3.4 MB 75.6 kB/s eta 0:00:12
#      ----------------------------- ---------- 2.5/3.4 MB 75.6 kB/s eta 0:00:12
#      ----------------------------- ---------- 2.6/3.4 MB 75.6 kB/s eta 0:00:12
#      ----------------------------- ---------- 2.6/3.4 MB 75.6 kB/s eta 0:00:12
#      ----------------------------- ---------- 2.6/3.4 MB 75.6 kB/s eta 0:00:12
#      ----------------------------- ---------- 2.6/3.4 MB 75.6 kB/s eta 0:00:12
#      ------------------------------ --------- 2.6/3.4 MB 75.9 kB/s eta 0:00:12
#      ------------------------------ --------- 2.6/3.4 MB 75.9 kB/s eta 0:00:12
#      ------------------------------ --------- 2.6/3.4 MB 75.9 kB/s eta 0:00:12
#      ------------------------------ --------- 2.6/3.4 MB 76.2 kB/s eta 0:00:11
#      ------------------------------ --------- 2.6/3.4 MB 76.2 kB/s eta 0:00:11
#      ------------------------------ --------- 2.6/3.4 MB 76.2 kB/s eta 0:00:11
#      ------------------------------ --------- 2.6/3.4 MB 76.2 kB/s eta 0:00:11
#      ------------------------------ --------- 2.6/3.4 MB 76.2 kB/s eta 0:00:11
#      ------------------------------ --------- 2.6/3.4 MB 76.2 kB/s eta 0:00:11
#      ------------------------------ --------- 2.6/3.4 MB 76.2 kB/s eta 0:00:11
#      ------------------------------ --------- 2.6/3.4 MB 76.2 kB/s eta 0:00:11
#      ------------------------------ --------- 2.6/3.4 MB 76.2 kB/s eta 0:00:11
#      ------------------------------ --------- 2.6/3.4 MB 76.2 kB/s eta 0:00:11
#      ------------------------------ --------- 2.6/3.4 MB 76.2 kB/s eta 0:00:11
#      ------------------------------ --------- 2.6/3.4 MB 76.2 kB/s eta 0:00:11
#      ------------------------------ --------- 2.6/3.4 MB 76.2 kB/s eta 0:00:11
#      ------------------------------ --------- 2.6/3.4 MB 76.2 kB/s eta 0:00:11
#      ------------------------------ --------- 2.6/3.4 MB 76.1 kB/s eta 0:00:11
#      ------------------------------ --------- 2.6/3.4 MB 76.1 kB/s eta 0:00:11
#      ------------------------------ --------- 2.6/3.4 MB 76.1 kB/s eta 0:00:11
#      ------------------------------ --------- 2.6/3.4 MB 76.1 kB/s eta 0:00:11
#      ------------------------------ --------- 2.6/3.4 MB 75.9 kB/s eta 0:00:11
#      ------------------------------ --------- 2.6/3.4 MB 75.9 kB/s eta 0:00:11
#      ------------------------------- -------- 2.7/3.4 MB 76.6 kB/s eta 0:00:10
#      ------------------------------- -------- 2.7/3.4 MB 76.6 kB/s eta 0:00:10
#      ------------------------------- -------- 2.7/3.4 MB 76.6 kB/s eta 0:00:10
#      ------------------------------- -------- 2.7/3.4 MB 76.9 kB/s eta 0:00:10
#      ------------------------------- -------- 2.7/3.4 MB 76.9 kB/s eta 0:00:10
#      ------------------------------- -------- 2.7/3.4 MB 76.9 kB/s eta 0:00:10
#      ------------------------------- -------- 2.7/3.4 MB 76.9 kB/s eta 0:00:10
#      ------------------------------- -------- 2.7/3.4 MB 78.3 kB/s eta 0:00:10
#      ------------------------------- -------- 2.7/3.4 MB 78.3 kB/s eta 0:00:10
#      ------------------------------- -------- 2.7/3.4 MB 78.3 kB/s eta 0:00:10
#      ------------------------------- -------- 2.7/3.4 MB 78.3 kB/s eta 0:00:10
#      ------------------------------- -------- 2.7/3.4 MB 78.3 kB/s eta 0:00:10
#      ------------------------------- -------- 2.7/3.4 MB 78.4 kB/s eta 0:00:10
#      ------------------------------- -------- 2.7/3.4 MB 78.4 kB/s eta 0:00:10
#      ------------------------------- -------- 2.7/3.4 MB 78.5 kB/s eta 0:00:09
#      ------------------------------- -------- 2.7/3.4 MB 78.5 kB/s eta 0:00:09
#      ------------------------------- -------- 2.7/3.4 MB 78.5 kB/s eta 0:00:09
#      -------------------------------- ------- 2.7/3.4 MB 78.8 kB/s eta 0:00:09
#      -------------------------------- ------- 2.7/3.4 MB 78.8 kB/s eta 0:00:09
#      -------------------------------- ------- 2.8/3.4 MB 79.2 kB/s eta 0:00:09
#      -------------------------------- ------- 2.8/3.4 MB 79.2 kB/s eta 0:00:09
#      -------------------------------- ------- 2.8/3.4 MB 79.2 kB/s eta 0:00:09
#      -------------------------------- ------- 2.8/3.4 MB 79.2 kB/s eta 0:00:09
#      -------------------------------- ------- 2.8/3.4 MB 79.1 kB/s eta 0:00:09
#      -------------------------------- ------- 2.8/3.4 MB 79.1 kB/s eta 0:00:09
#      -------------------------------- ------- 2.8/3.4 MB 79.1 kB/s eta 0:00:09
#      -------------------------------- ------- 2.8/3.4 MB 79.1 kB/s eta 0:00:09
#      -------------------------------- ------- 2.8/3.4 MB 78.6 kB/s eta 0:00:08
#      -------------------------------- ------- 2.8/3.4 MB 78.6 kB/s eta 0:00:08
#      -------------------------------- ------- 2.8/3.4 MB 78.6 kB/s eta 0:00:08
#      -------------------------------- ------- 2.8/3.4 MB 78.6 kB/s eta 0:00:08
#      -------------------------------- ------- 2.8/3.4 MB 78.5 kB/s eta 0:00:08
#      -------------------------------- ------- 2.8/3.4 MB 78.5 kB/s eta 0:00:08
#      -------------------------------- ------- 2.8/3.4 MB 78.5 kB/s eta 0:00:08
#      -------------------------------- ------- 2.8/3.4 MB 78.5 kB/s eta 0:00:08
#      --------------------------------- ------ 2.8/3.4 MB 78.7 kB/s eta 0:00:08
#      --------------------------------- ------ 2.8/3.4 MB 78.7 kB/s eta 0:00:08
#      --------------------------------- ------ 2.8/3.4 MB 78.7 kB/s eta 0:00:08
#      --------------------------------- ------ 2.8/3.4 MB 78.7 kB/s eta 0:00:08
#      --------------------------------- ------ 2.8/3.4 MB 78.9 kB/s eta 0:00:08
#      --------------------------------- ------ 2.8/3.4 MB 78.9 kB/s eta 0:00:08
#      --------------------------------- ------ 2.8/3.4 MB 78.9 kB/s eta 0:00:08
#      --------------------------------- ------ 2.9/3.4 MB 78.9 kB/s eta 0:00:08
#      --------------------------------- ------ 2.9/3.4 MB 78.9 kB/s eta 0:00:08
#      --------------------------------- ------ 2.9/3.4 MB 78.9 kB/s eta 0:00:08
#      --------------------------------- ------ 2.9/3.4 MB 79.2 kB/s eta 0:00:07
#      --------------------------------- ------ 2.9/3.4 MB 79.2 kB/s eta 0:00:07
#      --------------------------------- ------ 2.9/3.4 MB 79.2 kB/s eta 0:00:07
#      --------------------------------- ------ 2.9/3.4 MB 79.2 kB/s eta 0:00:07
#      --------------------------------- ------ 2.9/3.4 MB 79.2 kB/s eta 0:00:07
#      --------------------------------- ------ 2.9/3.4 MB 80.0 kB/s eta 0:00:07
#      --------------------------------- ------ 2.9/3.4 MB 80.0 kB/s eta 0:00:07
#      --------------------------------- ------ 2.9/3.4 MB 80.0 kB/s eta 0:00:07
#      --------------------------------- ------ 2.9/3.4 MB 80.0 kB/s eta 0:00:07
#      --------------------------------- ------ 2.9/3.4 MB 80.2 kB/s eta 0:00:07
#      --------------------------------- ------ 2.9/3.4 MB 80.2 kB/s eta 0:00:07
#      --------------------------------- ------ 2.9/3.4 MB 80.2 kB/s eta 0:00:07
#      ---------------------------------- ----- 2.9/3.4 MB 80.4 kB/s eta 0:00:07
#      ---------------------------------- ----- 2.9/3.4 MB 80.4 kB/s eta 0:00:07
#      ---------------------------------- ----- 2.9/3.4 MB 80.4 kB/s eta 0:00:07
#      ---------------------------------- ----- 2.9/3.4 MB 80.4 kB/s eta 0:00:07
#      ---------------------------------- ----- 2.9/3.4 MB 80.5 kB/s eta 0:00:07
#      ---------------------------------- ----- 2.9/3.4 MB 80.5 kB/s eta 0:00:07
#      ---------------------------------- ----- 3.0/3.4 MB 80.9 kB/s eta 0:00:06
#      ---------------------------------- ----- 3.0/3.4 MB 80.9 kB/s eta 0:00:06
#      ---------------------------------- ----- 3.0/3.4 MB 80.9 kB/s eta 0:00:06
#      ---------------------------------- ----- 3.0/3.4 MB 80.9 kB/s eta 0:00:06
#      ---------------------------------- ----- 3.0/3.4 MB 81.1 kB/s eta 0:00:06
#      ---------------------------------- ----- 3.0/3.4 MB 81.1 kB/s eta 0:00:06
#      ---------------------------------- ----- 3.0/3.4 MB 81.1 kB/s eta 0:00:06
#      ---------------------------------- ----- 3.0/3.4 MB 81.4 kB/s eta 0:00:06
#      ---------------------------------- ----- 3.0/3.4 MB 81.4 kB/s eta 0:00:06
#      ---------------------------------- ----- 3.0/3.4 MB 81.4 kB/s eta 0:00:06
#      ----------------------------------- ---- 3.0/3.4 MB 81.8 kB/s eta 0:00:06
#      ----------------------------------- ---- 3.0/3.4 MB 81.8 kB/s eta 0:00:06
#      ----------------------------------- ---- 3.0/3.4 MB 81.8 kB/s eta 0:00:06
#      ----------------------------------- ---- 3.0/3.4 MB 81.8 kB/s eta 0:00:06
#      ----------------------------------- ---- 3.0/3.4 MB 81.6 kB/s eta 0:00:05
#      ----------------------------------- ---- 3.0/3.4 MB 81.6 kB/s eta 0:00:05
#      ----------------------------------- ---- 3.0/3.4 MB 81.6 kB/s eta 0:00:05
#      ----------------------------------- ---- 3.0/3.4 MB 81.6 kB/s eta 0:00:05
#      ----------------------------------- ---- 3.0/3.4 MB 82.1 kB/s eta 0:00:05
#      ----------------------------------- ---- 3.1/3.4 MB 82.1 kB/s eta 0:00:05
#      ----------------------------------- ---- 3.1/3.4 MB 82.1 kB/s eta 0:00:05
#      ----------------------------------- ---- 3.1/3.4 MB 82.1 kB/s eta 0:00:05
#      ----------------------------------- ---- 3.1/3.4 MB 82.3 kB/s eta 0:00:05
#      ----------------------------------- ---- 3.1/3.4 MB 82.3 kB/s eta 0:00:05
#      ----------------------------------- ---- 3.1/3.4 MB 82.3 kB/s eta 0:00:05
#      ------------------------------------ --- 3.1/3.4 MB 82.6 kB/s eta 0:00:05
#      ------------------------------------ --- 3.1/3.4 MB 82.6 kB/s eta 0:00:05
#      ------------------------------------ --- 3.1/3.4 MB 82.6 kB/s eta 0:00:05
#      ------------------------------------ --- 3.1/3.4 MB 83.1 kB/s eta 0:00:04
#      ------------------------------------ --- 3.1/3.4 MB 83.1 kB/s eta 0:00:04
#      ------------------------------------ --- 3.1/3.4 MB 83.1 kB/s eta 0:00:04
#      ------------------------------------ --- 3.1/3.4 MB 83.4 kB/s eta 0:00:04
#      ------------------------------------ --- 3.1/3.4 MB 83.4 kB/s eta 0:00:04
#      ------------------------------------ --- 3.1/3.4 MB 83.4 kB/s eta 0:00:04
#      ------------------------------------ --- 3.1/3.4 MB 83.4 kB/s eta 0:00:04
#      ------------------------------------ --- 3.1/3.4 MB 83.4 kB/s eta 0:00:04
#      ------------------------------------ --- 3.1/3.4 MB 83.4 kB/s eta 0:00:04
#      ------------------------------------ --- 3.1/3.4 MB 83.4 kB/s eta 0:00:04
#      ------------------------------------ --- 3.1/3.4 MB 83.4 kB/s eta 0:00:04
#      ------------------------------------ --- 3.2/3.4 MB 83.5 kB/s eta 0:00:04
#      ------------------------------------ --- 3.2/3.4 MB 83.5 kB/s eta 0:00:04
#      ------------------------------------ --- 3.2/3.4 MB 83.5 kB/s eta 0:00:04
#      ------------------------------------ --- 3.2/3.4 MB 83.5 kB/s eta 0:00:04
#      ------------------------------------- -- 3.2/3.4 MB 84.0 kB/s eta 0:00:03
#      ------------------------------------- -- 3.2/3.4 MB 84.0 kB/s eta 0:00:03
#      ------------------------------------- -- 3.2/3.4 MB 84.0 kB/s eta 0:00:03
#      ------------------------------------- -- 3.2/3.4 MB 84.0 kB/s eta 0:00:03
#      ------------------------------------- -- 3.2/3.4 MB 83.9 kB/s eta 0:00:03
#      ------------------------------------- -- 3.2/3.4 MB 83.9 kB/s eta 0:00:03
#      ------------------------------------- -- 3.2/3.4 MB 84.3 kB/s eta 0:00:03
#      ------------------------------------- -- 3.2/3.4 MB 84.3 kB/s eta 0:00:03
#      ------------------------------------- -- 3.2/3.4 MB 84.3 kB/s eta 0:00:03
#      ------------------------------------- -- 3.2/3.4 MB 84.3 kB/s eta 0:00:03
#      ------------------------------------- -- 3.2/3.4 MB 84.6 kB/s eta 0:00:03
#      ------------------------------------- -- 3.2/3.4 MB 84.6 kB/s eta 0:00:03
#      ------------------------------------- -- 3.2/3.4 MB 84.6 kB/s eta 0:00:03
#      ------------------------------------- -- 3.2/3.4 MB 84.8 kB/s eta 0:00:03
#      ------------------------------------- -- 3.2/3.4 MB 84.8 kB/s eta 0:00:03
#      ------------------------------------- -- 3.2/3.4 MB 84.8 kB/s eta 0:00:03
#      ------------------------------------- -- 3.2/3.4 MB 84.8 kB/s eta 0:00:03
#      ------------------------------------- -- 3.2/3.4 MB 84.8 kB/s eta 0:00:03
#      ------------------------------------- -- 3.2/3.4 MB 84.8 kB/s eta 0:00:03
#      -------------------------------------- - 3.3/3.4 MB 85.7 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 85.7 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 85.7 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 85.9 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 85.9 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 85.9 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      -------------------------------------- - 3.3/3.4 MB 86.0 kB/s eta 0:00:02
#      ---------------------------------------  3.4/3.4 MB 85.9 kB/s eta 0:00:01
#      ---------------------------------------- 3.4/3.4 MB 85.9 kB/s eta 0:00:00
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.7.2

# %%
from spellchecker import SpellChecker

# %%
checker = SpellChecker()

# %%
[checker.correction(i) for i in std_tokens]
# Out:
# ['the',
#  'nikita',
#  'corpus',
#  'is',
#  'a',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'of',
#  'question',
#  'and',
#  'sentence',
#  'pairs',
#  ',',
#  'collected',
#  'and',
#  'annotated',
#  'for',
#  'research',
#  'on',
#  None,
#  'question',
#  'answering',
#  '.',
#  'in',
#  'order',
#  'to',
#  'reflect',
#  'the',
#  'true',
#  'information',
#  'need',
#  'of',
#  'general',
#  'users',
#  ',',
#  'we',
#  'used',
#  'bing',
#  'query',
#  'logs',
#  'as',
#  'the',
#  'question',
#  'source',
#  '.',
#  'each',
#  'question',
#  'is',
#  'linked',
#  'to',
#  'a',
#  'wikipedia',
#  'page',
#  'that',
#  'potentially',
#  'has',
#  'the',
#  'answer',
#  '.',
#  'because',
#  'the',
#  'summary',
#  'section',
#  'of',
#  'a',
#  'wikipedia',
#  'page',
#  'provides',
#  'the',
#  'basic',
#  'and',
#  'usually',
#  'most',
#  'important',
#  'information',
#  'about',
#  'the',
#  'topic',
#  ',',
#  'we',
#  'used',
#  'sentences',
#  'in',
#  'this',
#  'section',
#  'as',
#  'the',
#  'candidate',
#  'answers',
#  '.',
#  'with',
#  'the',
#  'help',
#  'of',
#  None,
#  ',',
#  'we',
#  'included',
#  None,
#  'questions',
#  'and',
#  None,
#  'sentences',
#  'in',
#  'the',
#  None,
#  ',',
#  'where',
#  None,
#  'sentences',
#  'were',
#  'labeled',
#  'as',
#  'answer',
#  'sentences',
#  'to',
#  'their',
#  'corresponding',
#  'questions',
#  '.',
#  'more',
#  'detail',
#  'of',
#  'this',
#  'corpus',
#  'can',
#  'be',
#  'found',
#  'in',
#  'our',
#  None,
#  'paper',
#  ',',
#  'i',
#  'nikita',
#  ':',
#  'a',
#  'challenge',
#  None,
#  'for',
#  None,
#  'question',
#  'answering',
#  'i',
#  '[',
#  'yang',
#  'et',
#  'al',
#  '.',
#  '2015',
#  ']',
#  '.',
#  'in',
#  'addition',
#  ',',
#  'this',
#  'download',
#  'also',
#  'includes',
#  'the',
#  'experimental',
#  'results',
#  'in',
#  'the',
#  'paper',
#  ',',
#  'an',
#  'evaluation',
#  'script',
#  'for',
#  'judging',
#  'the',
#  'i',
#  'answer',
#  'triggering',
#  'i',
#  'task',
#  ',',
#  'as',
#  'well',
#  'as',
#  'the',
#  'answer',
#  'phrases',
#  'labeled',
#  'by',
#  'the',
#  'authors',
#  'of',
#  'the',
#  'paper',
#  '.']

# %% [markdown]
# # Stemming

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
stemmer = PorterStemmer()

# %%
std_tokens
# Out:
# ['the',
#  'wikiqa',
#  'corpus',
#  'is',
#  'a',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'of',
#  'question',
#  'and',
#  'sentence',
#  'pairs',
#  ',',
#  'collected',
#  'and',
#  'annotated',
#  'for',
#  'research',
#  'on',
#  'open-domain',
#  'question',
#  'answering',
#  '.',
#  'in',
#  'order',
#  'to',
#  'reflect',
#  'the',
#  'true',
#  'information',
#  'need',
#  'of',
#  'general',
#  'users',
#  ',',
#  'we',
#  'used',
#  'bing',
#  'query',
#  'logs',
#  'as',
#  'the',
#  'question',
#  'source',
#  '.',
#  'each',
#  'question',
#  'is',
#  'linked',
#  'to',
#  'a',
#  'wikipedia',
#  'page',
#  'that',
#  'potentially',
#  'has',
#  'the',
#  'answer',
#  '.',
#  'because',
#  'the',
#  'summary',
#  'section',
#  'of',
#  'a',
#  'wikipedia',
#  'page',
#  'provides',
#  'the',
#  'basic',
#  'and',
#  'usually',
#  'most',
#  'important',
#  'information',
#  'about',
#  'the',
#  'topic',
#  ',',
#  'we',
#  'used',
#  'sentences',
#  'in',
#  'this',
#  'section',
#  'as',
#  'the',
#  'candidate',
#  'answers',
#  '.',
#  'with',
#  'the',
#  'help',
#  'of',
#  'crowdsourcing',
#  ',',
#  'we',
#  'included',
#  '3,047',
#  'questions',
#  'and',
#  '29,258',
#  'sentences',
#  'in',
#  'the',
#  'dataset',
#  ',',
#  'where',
#  '1,473',
#  'sentences',
#  'were',
#  'labeled',
#  'as',
#  'answer',
#  'sentences',
#  'to',
#  'their',
#  'corresponding',
#  'questions',
#  '.',
#  'more',
#  'detail',
#  'of',
#  'this',
#  'corpus',
#  'can',
#  'be',
#  'found',
#  'in',
#  'our',
#  'emnlp-2015',
#  'paper',
#  ',',
#  '``',
#  'wikiqa',
#  ':',
#  'a',
#  'challenge',
#  'dataset',
#  'for',
#  'open-domain',
#  'question',
#  'answering',
#  "''",
#  '[',
#  'yang',
#  'et',
#  'al',
#  '.',
#  '2015',
#  ']',
#  '.',
#  'in',
#  'addition',
#  ',',
#  'this',
#  'download',
#  'also',
#  'includes',
#  'the',
#  'experimental',
#  'results',
#  'in',
#  'the',
#  'paper',
#  ',',
#  'an',
#  'evaluation',
#  'script',
#  'for',
#  'judging',
#  'the',
#  '``',
#  'answer',
#  'triggering',
#  "''",
#  'task',
#  ',',
#  'as',
#  'well',
#  'as',
#  'the',
#  'answer',
#  'phrases',
#  'labeled',
#  'by',
#  'the',
#  'authors',
#  'of',
#  'the',
#  'paper',
#  '.']

# %%
[stemmer.stem(i) for i in std_tokens]
# Out:
# ['the',
#  'wikiqa',
#  'corpu',
#  'is',
#  'a',
#  'new',
#  'publicli',
#  'avail',
#  'set',
#  'of',
#  'question',
#  'and',
#  'sentenc',
#  'pair',
#  ',',
#  'collect',
#  'and',
#  'annot',
#  'for',
#  'research',
#  'on',
#  'open-domain',
#  'question',
#  'answer',
#  '.',
#  'in',
#  'order',
#  'to',
#  'reflect',
#  'the',
#  'true',
#  'inform',
#  'need',
#  'of',
#  'gener',
#  'user',
#  ',',
#  'we',
#  'use',
#  'bing',
#  'queri',
#  'log',
#  'as',
#  'the',
#  'question',
#  'sourc',
#  '.',
#  'each',
#  'question',
#  'is',
#  'link',
#  'to',
#  'a',
#  'wikipedia',
#  'page',
#  'that',
#  'potenti',
#  'ha',
#  'the',
#  'answer',
#  '.',
#  'becaus',
#  'the',
#  'summari',
#  'section',
#  'of',
#  'a',
#  'wikipedia',
#  'page',
#  'provid',
#  'the',
#  'basic',
#  'and',
#  'usual',
#  'most',
#  'import',
#  'inform',
#  'about',
#  'the',
#  'topic',
#  ',',
#  'we',
#  'use',
#  'sentenc',
#  'in',
#  'thi',
#  'section',
#  'as',
#  'the',
#  'candid',
#  'answer',
#  '.',
#  'with',
#  'the',
#  'help',
#  'of',
#  'crowdsourc',
#  ',',
#  'we',
#  'includ',
#  '3,047',
#  'question',
#  'and',
#  '29,258',
#  'sentenc',
#  'in',
#  'the',
#  'dataset',
#  ',',
#  'where',
#  '1,473',
#  'sentenc',
#  'were',
#  'label',
#  'as',
#  'answer',
#  'sentenc',
#  'to',
#  'their',
#  'correspond',
#  'question',
#  '.',
#  'more',
#  'detail',
#  'of',
#  'thi',
#  'corpu',
#  'can',
#  'be',
#  'found',
#  'in',
#  'our',
#  'emnlp-2015',
#  'paper',
#  ',',
#  '``',
#  'wikiqa',
#  ':',
#  'a',
#  'challeng',
#  'dataset',
#  'for',
#  'open-domain',
#  'question',
#  'answer',
#  "''",
#  '[',
#  'yang',
#  'et',
#  'al',
#  '.',
#  '2015',
#  ']',
#  '.',
#  'in',
#  'addit',
#  ',',
#  'thi',
#  'download',
#  'also',
#  'includ',
#  'the',
#  'experiment',
#  'result',
#  'in',
#  'the',
#  'paper',
#  ',',
#  'an',
#  'evalu',
#  'script',
#  'for',
#  'judg',
#  'the',
#  '``',
#  'answer',
#  'trigger',
#  "''",
#  'task',
#  ',',
#  'as',
#  'well',
#  'as',
#  'the',
#  'answer',
#  'phrase',
#  'label',
#  'by',
#  'the',
#  'author',
#  'of',
#  'the',
#  'paper',
#  '.']

# %% [markdown]
# # Lemmatizer

# %%
lemm = WordNetLemmatizer()

# %%
std_tokens
# Out:
# ['the',
#  'wikiqa',
#  'corpus',
#  'is',
#  'a',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'of',
#  'question',
#  'and',
#  'sentence',
#  'pairs',
#  ',',
#  'collected',
#  'and',
#  'annotated',
#  'for',
#  'research',
#  'on',
#  'open-domain',
#  'question',
#  'answering',
#  '.',
#  'in',
#  'order',
#  'to',
#  'reflect',
#  'the',
#  'true',
#  'information',
#  'need',
#  'of',
#  'general',
#  'users',
#  ',',
#  'we',
#  'used',
#  'bing',
#  'query',
#  'logs',
#  'as',
#  'the',
#  'question',
#  'source',
#  '.',
#  'each',
#  'question',
#  'is',
#  'linked',
#  'to',
#  'a',
#  'wikipedia',
#  'page',
#  'that',
#  'potentially',
#  'has',
#  'the',
#  'answer',
#  '.',
#  'because',
#  'the',
#  'summary',
#  'section',
#  'of',
#  'a',
#  'wikipedia',
#  'page',
#  'provides',
#  'the',
#  'basic',
#  'and',
#  'usually',
#  'most',
#  'important',
#  'information',
#  'about',
#  'the',
#  'topic',
#  ',',
#  'we',
#  'used',
#  'sentences',
#  'in',
#  'this',
#  'section',
#  'as',
#  'the',
#  'candidate',
#  'answers',
#  '.',
#  'with',
#  'the',
#  'help',
#  'of',
#  'crowdsourcing',
#  ',',
#  'we',
#  'included',
#  '3,047',
#  'questions',
#  'and',
#  '29,258',
#  'sentences',
#  'in',
#  'the',
#  'dataset',
#  ',',
#  'where',
#  '1,473',
#  'sentences',
#  'were',
#  'labeled',
#  'as',
#  'answer',
#  'sentences',
#  'to',
#  'their',
#  'corresponding',
#  'questions',
#  '.',
#  'more',
#  'detail',
#  'of',
#  'this',
#  'corpus',
#  'can',
#  'be',
#  'found',
#  'in',
#  'our',
#  'emnlp-2015',
#  'paper',
#  ',',
#  '``',
#  'wikiqa',
#  ':',
#  'a',
#  'challenge',
#  'dataset',
#  'for',
#  'open-domain',
#  'question',
#  'answering',
#  "''",
#  '[',
#  'yang',
#  'et',
#  'al',
#  '.',
#  '2015',
#  ']',
#  '.',
#  'in',
#  'addition',
#  ',',
#  'this',
#  'download',
#  'also',
#  'includes',
#  'the',
#  'experimental',
#  'results',
#  'in',
#  'the',
#  'paper',
#  ',',
#  'an',
#  'evaluation',
#  'script',
#  'for',
#  'judging',
#  'the',
#  '``',
#  'answer',
#  'triggering',
#  "''",
#  'task',
#  ',',
#  'as',
#  'well',
#  'as',
#  'the',
#  'answer',
#  'phrases',
#  'labeled',
#  'by',
#  'the',
#  'authors',
#  'of',
#  'the',
#  'paper',
#  '.']

# %%
[lemm.lemmatize(i) for i in std_tokens]
# Out:
# ['the',
#  'wikiqa',
#  'corpus',
#  'is',
#  'a',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'of',
#  'question',
#  'and',
#  'sentence',
#  'pair',
#  ',',
#  'collected',
#  'and',
#  'annotated',
#  'for',
#  'research',
#  'on',
#  'open-domain',
#  'question',
#  'answering',
#  '.',
#  'in',
#  'order',
#  'to',
#  'reflect',
#  'the',
#  'true',
#  'information',
#  'need',
#  'of',
#  'general',
#  'user',
#  ',',
#  'we',
#  'used',
#  'bing',
#  'query',
#  'log',
#  'a',
#  'the',
#  'question',
#  'source',
#  '.',
#  'each',
#  'question',
#  'is',
#  'linked',
#  'to',
#  'a',
#  'wikipedia',
#  'page',
#  'that',
#  'potentially',
#  'ha',
#  'the',
#  'answer',
#  '.',
#  'because',
#  'the',
#  'summary',
#  'section',
#  'of',
#  'a',
#  'wikipedia',
#  'page',
#  'provides',
#  'the',
#  'basic',
#  'and',
#  'usually',
#  'most',
#  'important',
#  'information',
#  'about',
#  'the',
#  'topic',
#  ',',
#  'we',
#  'used',
#  'sentence',
#  'in',
#  'this',
#  'section',
#  'a',
#  'the',
#  'candidate',
#  'answer',
#  '.',
#  'with',
#  'the',
#  'help',
#  'of',
#  'crowdsourcing',
#  ',',
#  'we',
#  'included',
#  '3,047',
#  'question',
#  'and',
#  '29,258',
#  'sentence',
#  'in',
#  'the',
#  'dataset',
#  ',',
#  'where',
#  '1,473',
#  'sentence',
#  'were',
#  'labeled',
#  'a',
#  'answer',
#  'sentence',
#  'to',
#  'their',
#  'corresponding',
#  'question',
#  '.',
#  'more',
#  'detail',
#  'of',
#  'this',
#  'corpus',
#  'can',
#  'be',
#  'found',
#  'in',
#  'our',
#  'emnlp-2015',
#  'paper',
#  ',',
#  '``',
#  'wikiqa',
#  ':',
#  'a',
#  'challenge',
#  'dataset',
#  'for',
#  'open-domain',
#  'question',
#  'answering',
#  "''",
#  '[',
#  'yang',
#  'et',
#  'al',
#  '.',
#  '2015',
#  ']',
#  '.',
#  'in',
#  'addition',
#  ',',
#  'this',
#  'download',
#  'also',
#  'includes',
#  'the',
#  'experimental',
#  'result',
#  'in',
#  'the',
#  'paper',
#  ',',
#  'an',
#  'evaluation',
#  'script',
#  'for',
#  'judging',
#  'the',
#  '``',
#  'answer',
#  'triggering',
#  "''",
#  'task',
#  ',',
#  'a',
#  'well',
#  'a',
#  'the',
#  'answer',
#  'phrase',
#  'labeled',
#  'by',
#  'the',
#  'author',
#  'of',
#  'the',
#  'paper',
#  '.']

# %% [markdown]
# # POS

# %%
import nltk

# %%
input_sent = "wikiqa corpus new publicly available set question sentence pairs , collected annotated research open-domain question answering . order reflect true information need general users , used bing query logs question source . question linked wikipedia page potentially answer . summary section wikipedia page provides basic usually important information topic , used sentences section candidate answers . help crowdsourcing , included  ,  questions  ,  sentences dataset ,  ,  sentences labeled answer sentences corresponding questions . detail corpus found emnlp-  paper , `` wikiqa : challenge dataset open-domain question answering '' [ yang et al .   ] . addition , download also includes experimental results paper , evaluation script judging `` answer triggering '' task , well answer phrases labeled authors paper ."

# %%
tokens = nltk.word_tokenize(input_sent)

# %%
tokens
# Out:
# ['wikiqa',
#  'corpus',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'question',
#  'sentence',
#  'pairs',
#  ',',
#  'collected',
#  'annotated',
#  'research',
#  'open-domain',
#  'question',
#  'answering',
#  '.',
#  'order',
#  'reflect',
#  'true',
#  'information',
#  'need',
#  'general',
#  'users',
#  ',',
#  'used',
#  'bing',
#  'query',
#  'logs',
#  'question',
#  'source',
#  '.',
#  'question',
#  'linked',
#  'wikipedia',
#  'page',
#  'potentially',
#  'answer',
#  '.',
#  'summary',
#  'section',
#  'wikipedia',
#  'page',
#  'provides',
#  'basic',
#  'usually',
#  'important',
#  'information',
#  'topic',
#  ',',
#  'used',
#  'sentences',
#  'section',
#  'candidate',
#  'answers',
#  '.',
#  'help',
#  'crowdsourcing',
#  ',',
#  'included',
#  ',',
#  'questions',
#  ',',
#  'sentences',
#  'dataset',
#  ',',
#  ',',
#  'sentences',
#  'labeled',
#  'answer',
#  'sentences',
#  'corresponding',
#  'questions',
#  '.',
#  'detail',
#  'corpus',
#  'found',
#  'emnlp-',
#  'paper',
#  ',',
#  '``',
#  'wikiqa',
#  ':',
#  'challenge',
#  'dataset',
#  'open-domain',
#  'question',
#  'answering',
#  '``',
#  '[',
#  'yang',
#  'et',
#  'al',
#  '.',
#  ']',
#  '.',
#  'addition',
#  ',',
#  'download',
#  'also',
#  'includes',
#  'experimental',
#  'results',
#  'paper',
#  ',',
#  'evaluation',
#  'script',
#  'judging',
#  '``',
#  'answer',
#  'triggering',
#  '``',
#  'task',
#  ',',
#  'well',
#  'answer',
#  'phrases',
#  'labeled',
#  'authors',
#  'paper',
#  '.']

# %%
pos_tagged_words = nltk.pos_tag(tokens)

# %%
noun_list = []
non_noun = []
for i,j in pos_tagged_words:
    if j not in ['PRP','NN']:
        print(i)
        non_noun.append(i)
    else:
        print(i)
        noun_list.append(i)
# Out:
# wikiqa
# corpus
# new
# publicly
# available
# set
# question
# sentence
# pairs
# ,
# collected
# annotated
# research
# open-domain
# question
# answering
# .
# order
# reflect
# true
# information
# need
# general
# users
# ,
# used
# bing
# query
# logs
# question
# source
# .
# question
# linked
# wikipedia
# page
# potentially
# answer
# .
# summary
# section
# wikipedia
# page
# provides
# basic
# usually
# important
# information
# topic
# ,
# used
# sentences
# section
# candidate
# answers
# .
# help
# crowdsourcing
# ,
# included
# ,
# questions
# ,
# sentences
# dataset
# ,
# ,
# sentences
# labeled
# answer
# sentences
# corresponding
# questions
# .
# detail
# corpus
# found
# emnlp-
# paper
# ,
# ``
# wikiqa
# :
# challenge
# dataset
# open-domain
# question
# answering
# ``
# [
# yang
# et
# al
# .
# ]
# .
# addition
# ,
# download
# also
# includes
# experimental
# results
# paper
# ,
# evaluation
# script
# judging
# ``
# answer
# triggering
# ``
# task
# ,
# well
# answer
# phrases
# labeled
# authors
# paper
# .

# %% [markdown]
# # N grams

# %%
from nltk.util import ngrams

# %%
input_text = "wikiqa corpus new publicly available set question sentence pairs , collected annotated research open-domain question answering . order reflect true information need general users , used bing query logs question source . question linked wikipedia page potentially answer . summary section wikipedia page provides basic usually important information topic , used sentences section candidate answers . help crowdsourcing , included  ,  questions  ,  sentences dataset ,  ,  sentences labeled answer sentences corresponding questions . detail corpus found emnlp-  paper , `` wikiqa : challenge dataset open-domain question answering '' [ yang et al .   ] . addition , download also includes experimental results paper , evaluation script judging `` answer triggering '' task , well answer phrases labeled authors paper ."

# %%
input_text
tokens = word_tokenize(input_text)

# %%
len(tokens)
# Out:
# 121

# %%
ngrams(tokens,2)

# %%
gram_2 = list(ngrams(tokens,2))

# %%
gram_2
# Out:
# [('wikiqa', 'corpus'),
#  ('corpus', 'new'),
#  ('new', 'publicly'),
#  ('publicly', 'available'),
#  ('available', 'set'),
#  ('set', 'question'),
#  ('question', 'sentence'),
#  ('sentence', 'pairs'),
#  ('pairs', ','),
#  (',', 'collected'),
#  ('collected', 'annotated'),
#  ('annotated', 'research'),
#  ('research', 'open-domain'),
#  ('open-domain', 'question'),
#  ('question', 'answering'),
#  ('answering', '.'),
#  ('.', 'order'),
#  ('order', 'reflect'),
#  ('reflect', 'true'),
#  ('true', 'information'),
#  ('information', 'need'),
#  ('need', 'general'),
#  ('general', 'users'),
#  ('users', ','),
#  (',', 'used'),
#  ('used', 'bing'),
#  ('bing', 'query'),
#  ('query', 'logs'),
#  ('logs', 'question'),
#  ('question', 'source'),
#  ('source', '.'),
#  ('.', 'question'),
#  ('question', 'linked'),
#  ('linked', 'wikipedia'),
#  ('wikipedia', 'page'),
#  ('page', 'potentially'),
#  ('potentially', 'answer'),
#  ('answer', '.'),
#  ('.', 'summary'),
#  ('summary', 'section'),
#  ('section', 'wikipedia'),
#  ('wikipedia', 'page'),
#  ('page', 'provides'),
#  ('provides', 'basic'),
#  ('basic', 'usually'),
#  ('usually', 'important'),
#  ('important', 'information'),
#  ('information', 'topic'),
#  ('topic', ','),
#  (',', 'used'),
#  ('used', 'sentences'),
#  ('sentences', 'section'),
#  ('section', 'candidate'),
#  ('candidate', 'answers'),
#  ('answers', '.'),
#  ('.', 'help'),
#  ('help', 'crowdsourcing'),
#  ('crowdsourcing', ','),
#  (',', 'included'),
#  ('included', ','),
#  (',', 'questions'),
#  ('questions', ','),
#  (',', 'sentences'),
#  ('sentences', 'dataset'),
#  ('dataset', ','),
#  (',', ','),
#  (',', 'sentences'),
#  ('sentences', 'labeled'),
#  ('labeled', 'answer'),
#  ('answer', 'sentences'),
#  ('sentences', 'corresponding'),
#  ('corresponding', 'questions'),
#  ('questions', '.'),
#  ('.', 'detail'),
#  ('detail', 'corpus'),
#  ('corpus', 'found'),
#  ('found', 'emnlp-'),
#  ('emnlp-', 'paper'),
#  ('paper', ','),
#  (',', '``'),
#  ('``', 'wikiqa'),
#  ('wikiqa', ':'),
#  (':', 'challenge'),
#  ('challenge', 'dataset'),
#  ('dataset', 'open-domain'),
#  ('open-domain', 'question'),
#  ('question', 'answering'),
#  ('answering', '``'),
#  ('``', '['),
#  ('[', 'yang'),
#  ('yang', 'et'),
#  ('et', 'al'),
#  ('al', '.'),
#  ('.', ']'),
#  (']', '.'),
#  ('.', 'addition'),
#  ('addition', ','),
#  (',', 'download'),
#  ('download', 'also'),
#  ('also', 'includes'),
#  ('includes', 'experimental'),
#  ('experimental', 'results'),
#  ('results', 'paper'),
#  ('paper', ','),
#  (',', 'evaluation'),
#  ('evaluation', 'script'),
#  ('script', 'judging'),
#  ('judging', '``'),
#  ('``', 'answer'),
#  ('answer', 'triggering'),
#  ('triggering', '``'),
#  ('``', 'task'),
#  ('task', ','),
#  (',', 'well'),
#  ('well', 'answer'),
#  ('answer', 'phrases'),
#  ('phrases', 'labeled'),
#  ('labeled', 'authors'),
#  ('authors', 'paper'),
#  ('paper', '.')]

# %%
gram_3 = list(ngrams(tokens,3))

# %%
gram_3
# Out:
# [('wikiqa', 'corpus', 'new'),
#  ('corpus', 'new', 'publicly'),
#  ('new', 'publicly', 'available'),
#  ('publicly', 'available', 'set'),
#  ('available', 'set', 'question'),
#  ('set', 'question', 'sentence'),
#  ('question', 'sentence', 'pairs'),
#  ('sentence', 'pairs', ','),
#  ('pairs', ',', 'collected'),
#  (',', 'collected', 'annotated'),
#  ('collected', 'annotated', 'research'),
#  ('annotated', 'research', 'open-domain'),
#  ('research', 'open-domain', 'question'),
#  ('open-domain', 'question', 'answering'),
#  ('question', 'answering', '.'),
#  ('answering', '.', 'order'),
#  ('.', 'order', 'reflect'),
#  ('order', 'reflect', 'true'),
#  ('reflect', 'true', 'information'),
#  ('true', 'information', 'need'),
#  ('information', 'need', 'general'),
#  ('need', 'general', 'users'),
#  ('general', 'users', ','),
#  ('users', ',', 'used'),
#  (',', 'used', 'bing'),
#  ('used', 'bing', 'query'),
#  ('bing', 'query', 'logs'),
#  ('query', 'logs', 'question'),
#  ('logs', 'question', 'source'),
#  ('question', 'source', '.'),
#  ('source', '.', 'question'),
#  ('.', 'question', 'linked'),
#  ('question', 'linked', 'wikipedia'),
#  ('linked', 'wikipedia', 'page'),
#  ('wikipedia', 'page', 'potentially'),
#  ('page', 'potentially', 'answer'),
#  ('potentially', 'answer', '.'),
#  ('answer', '.', 'summary'),
#  ('.', 'summary', 'section'),
#  ('summary', 'section', 'wikipedia'),
#  ('section', 'wikipedia', 'page'),
#  ('wikipedia', 'page', 'provides'),
#  ('page', 'provides', 'basic'),
#  ('provides', 'basic', 'usually'),
#  ('basic', 'usually', 'important'),
#  ('usually', 'important', 'information'),
#  ('important', 'information', 'topic'),
#  ('information', 'topic', ','),
#  ('topic', ',', 'used'),
#  (',', 'used', 'sentences'),
#  ('used', 'sentences', 'section'),
#  ('sentences', 'section', 'candidate'),
#  ('section', 'candidate', 'answers'),
#  ('candidate', 'answers', '.'),
#  ('answers', '.', 'help'),
#  ('.', 'help', 'crowdsourcing'),
#  ('help', 'crowdsourcing', ','),
#  ('crowdsourcing', ',', 'included'),
#  (',', 'included', ','),
#  ('included', ',', 'questions'),
#  (',', 'questions', ','),
#  ('questions', ',', 'sentences'),
#  (',', 'sentences', 'dataset'),
#  ('sentences', 'dataset', ','),
#  ('dataset', ',', ','),
#  (',', ',', 'sentences'),
#  (',', 'sentences', 'labeled'),
#  ('sentences', 'labeled', 'answer'),
#  ('labeled', 'answer', 'sentences'),
#  ('answer', 'sentences', 'corresponding'),
#  ('sentences', 'corresponding', 'questions'),
#  ('corresponding', 'questions', '.'),
#  ('questions', '.', 'detail'),
#  ('.', 'detail', 'corpus'),
#  ('detail', 'corpus', 'found'),
#  ('corpus', 'found', 'emnlp-'),
#  ('found', 'emnlp-', 'paper'),
#  ('emnlp-', 'paper', ','),
#  ('paper', ',', '``'),
#  (',', '``', 'wikiqa'),
#  ('``', 'wikiqa', ':'),
#  ('wikiqa', ':', 'challenge'),
#  (':', 'challenge', 'dataset'),
#  ('challenge', 'dataset', 'open-domain'),
#  ('dataset', 'open-domain', 'question'),
#  ('open-domain', 'question', 'answering'),
#  ('question', 'answering', '``'),
#  ('answering', '``', '['),
#  ('``', '[', 'yang'),
#  ('[', 'yang', 'et'),
#  ('yang', 'et', 'al'),
#  ('et', 'al', '.'),
#  ('al', '.', ']'),
#  ('.', ']', '.'),
#  (']', '.', 'addition'),
#  ('.', 'addition', ','),
#  ('addition', ',', 'download'),
#  (',', 'download', 'also'),
#  ('download', 'also', 'includes'),
#  ('also', 'includes', 'experimental'),
#  ('includes', 'experimental', 'results'),
#  ('experimental', 'results', 'paper'),
#  ('results', 'paper', ','),
#  ('paper', ',', 'evaluation'),
#  (',', 'evaluation', 'script'),
#  ('evaluation', 'script', 'judging'),
#  ('script', 'judging', '``'),
#  ('judging', '``', 'answer'),
#  ('``', 'answer', 'triggering'),
#  ('answer', 'triggering', '``'),
#  ('triggering', '``', 'task'),
#  ('``', 'task', ','),
#  ('task', ',', 'well'),
#  (',', 'well', 'answer'),
#  ('well', 'answer', 'phrases'),
#  ('answer', 'phrases', 'labeled'),
#  ('phrases', 'labeled', 'authors'),
#  ('labeled', 'authors', 'paper'),
#  ('authors', 'paper', '.')]

# %% [markdown]
# # Tokenization

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
sample_text = "wikiqa corpus new publicly available set question sentence pairs , collected annotated research open-domain question answering . order reflect true information need general users , used bing query logs question source . question linked wikipedia page potentially answer . summary section wikipedia page provides basic usually important information topic , used sentences section candidate answers . help crowdsourcing , included  ,  questions  ,  sentences dataset ,  ,  sentences labeled answer sentences corresponding questions . detail corpus found emnlp-  paper , `` wikiqa : challenge dataset open-domain question answering '' [ yang et al .   ] . addition , download also includes experimental results paper , evaluation script judging `` answer triggering '' task , well answer phrases labeled authors paper ."

# %%
word_tokenize(sample_text)
# Out:
# ['wikiqa',
#  'corpus',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'question',
#  'sentence',
#  'pairs',
#  ',',
#  'collected',
#  'annotated',
#  'research',
#  'open-domain',
#  'question',
#  'answering',
#  '.',
#  'order',
#  'reflect',
#  'true',
#  'information',
#  'need',
#  'general',
#  'users',
#  ',',
#  'used',
#  'bing',
#  'query',
#  'logs',
#  'question',
#  'source',
#  '.',
#  'question',
#  'linked',
#  'wikipedia',
#  'page',
#  'potentially',
#  'answer',
#  '.',
#  'summary',
#  'section',
#  'wikipedia',
#  'page',
#  'provides',
#  'basic',
#  'usually',
#  'important',
#  'information',
#  'topic',
#  ',',
#  'used',
#  'sentences',
#  'section',
#  'candidate',
#  'answers',
#  '.',
#  'help',
#  'crowdsourcing',
#  ',',
#  'included',
#  ',',
#  'questions',
#  ',',
#  'sentences',
#  'dataset',
#  ',',
#  ',',
#  'sentences',
#  'labeled',
#  'answer',
#  'sentences',
#  'corresponding',
#  'questions',
#  '.',
#  'detail',
#  'corpus',
#  'found',
#  'emnlp-',
#  'paper',
#  ',',
#  '``',
#  'wikiqa',
#  ':',
#  'challenge',
#  'dataset',
#  'open-domain',
#  'question',
#  'answering',
#  '``',
#  '[',
#  'yang',
#  'et',
#  'al',
#  '.',
#  ']',
#  '.',
#  'addition',
#  ',',
#  'download',
#  'also',
#  'includes',
#  'experimental',
#  'results',
#  'paper',
#  ',',
#  'evaluation',
#  'script',
#  'judging',
#  '``',
#  'answer',
#  'triggering',
#  '``',
#  'task',
#  ',',
#  'well',
#  'answer',
#  'phrases',
#  'labeled',
#  'authors',
#  'paper',
#  '.']

# %%
tokens = word_tokenize(sample_text)

# %%
tokens
# Out:
# ['wikiqa',
#  'corpus',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'question',
#  'sentence',
#  'pairs',
#  ',',
#  'collected',
#  'annotated',
#  'research',
#  'open-domain',
#  'question',
#  'answering',
#  '.',
#  'order',
#  'reflect',
#  'true',
#  'information',
#  'need',
#  'general',
#  'users',
#  ',',
#  'used',
#  'bing',
#  'query',
#  'logs',
#  'question',
#  'source',
#  '.',
#  'question',
#  'linked',
#  'wikipedia',
#  'page',
#  'potentially',
#  'answer',
#  '.',
#  'summary',
#  'section',
#  'wikipedia',
#  'page',
#  'provides',
#  'basic',
#  'usually',
#  'important',
#  'information',
#  'topic',
#  ',',
#  'used',
#  'sentences',
#  'section',
#  'candidate',
#  'answers',
#  '.',
#  'help',
#  'crowdsourcing',
#  ',',
#  'included',
#  ',',
#  'questions',
#  ',',
#  'sentences',
#  'dataset',
#  ',',
#  ',',
#  'sentences',
#  'labeled',
#  'answer',
#  'sentences',
#  'corresponding',
#  'questions',
#  '.',
#  'detail',
#  'corpus',
#  'found',
#  'emnlp-',
#  'paper',
#  ',',
#  '``',
#  'wikiqa',
#  ':',
#  'challenge',
#  'dataset',
#  'open-domain',
#  'question',
#  'answering',
#  '``',
#  '[',
#  'yang',
#  'et',
#  'al',
#  '.',
#  ']',
#  '.',
#  'addition',
#  ',',
#  'download',
#  'also',
#  'includes',
#  'experimental',
#  'results',
#  'paper',
#  ',',
#  'evaluation',
#  'script',
#  'judging',
#  '``',
#  'answer',
#  'triggering',
#  '``',
#  'task',
#  ',',
#  'well',
#  'answer',
#  'phrases',
#  'labeled',
#  'authors',
#  'paper',
#  '.']

# %%
sent_tokenize(sample_text)
# Out:
# ['wikiqa corpus new publicly available set question sentence pairs , collected annotated research open-domain question answering .',
#  'order reflect true information need general users , used bing query logs question source .',
#  'question linked wikipedia page potentially answer .',
#  'summary section wikipedia page provides basic usually important information topic , used sentences section candidate answers .',
#  'help crowdsourcing , included  ,  questions  ,  sentences dataset ,  ,  sentences labeled answer sentences corresponding questions .',
#  "detail corpus found emnlp-  paper , `` wikiqa : challenge dataset open-domain question answering '' [ yang et al .   ]",
#  '.',
#  "addition , download also includes experimental results paper , evaluation script judging `` answer triggering '' task , well answer phrases labeled authors paper ."]

# %%
" ".join(tokens)
# Out:
# 'wikiqa corpus new publicly available set question sentence pairs , collected annotated research open-domain question answering . order reflect true information need general users , used bing query logs question source . question linked wikipedia page potentially answer . summary section wikipedia page provides basic usually important information topic , used sentences section candidate answers . help crowdsourcing , included , questions , sentences dataset , , sentences labeled answer sentences corresponding questions . detail corpus found emnlp- paper , `` wikiqa : challenge dataset open-domain question answering `` [ yang et al . ] . addition , download also includes experimental results paper , evaluation script judging `` answer triggering `` task , well answer phrases labeled authors paper .'

# %% [markdown]
# # Text Classification

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.feature_extraction.text import TfidfVectorizer # Term Frequency 
from sklearn.metrics import classification_report

# %%
data = pd.read_csv("test.csv")

# %%
data
# Out:
#                                                    text  label
# 0     I always wrote this series off as being a comp...      0
# 1     1st watched 12/7/2002 - 3 out of 10(Dir-Steve ...      0
# 2     This movie was so poorly written and directed ...      0
# 3     The most interesting thing about Miryang (Secr...      1
# 4     when i first read about "berlin am meer" i did...      0
# ...                                                 ...    ...
# 4995  This is the kind of picture John Lassiter woul...      1
# 4996  A MUST SEE! I saw WHIPPED at a press screening...      1
# 4997  NBC should be ashamed. I wouldn't allow my chi...      0
# 4998  This movie is a clumsy mishmash of various gho...      0
# 4999  Formula movie about the illegitimate son of a ...      0
#
# [5000 rows x 2 columns]

# %%
data_text = data['text']
data_targ = data['label']

# %%
vect  = TfidfVectorizer()

# %%
train_data = vect.fit_transform(data_text)

# %%
len(vect.get_feature_names_out())
# Out:
# 39126

# %%
len(train_data.toarray()[0])
# Out:
# 39126

# %%
model = SVC(kernel="linear")

# %%
model.fit(train_data,data_targ)
# Out:
# SVC(kernel='linear')

# %%
predicted_data = model.predict(train_data)

# %%
print(classification_report(data_targ, predicted_data))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      2495
#            1       0.98      0.98      0.98      2505
#
#     accuracy                           0.98      5000
#    macro avg       0.98      0.98      0.98      5000
# weighted avg       0.98      0.98      0.98      5000

# %% [markdown]
# # Sentiment Analysis

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
sent = 'wikiqa corpus new publicly available set question sentence pairs , collected annotated research open-domain question answering . order reflect true information need general users , used bing query logs question source . question linked wikipedia page potentially answer . summary section wikipedia page provides basic usually important information topic , used sentences section candidate answers . help crowdsourcing , included , questions , sentences dataset , , sentences labeled answer sentences corresponding questions . detail corpus found emnlp- paper , `` wikiqa : challenge dataset open-domain question answering `` [ yang et al . ] . addition , download also includes experimental results paper , evaluation script judging `` answer triggering `` task , well answer phrases labeled authors paper .'

# %%
sent
# Out:
# 'wikiqa corpus new publicly available set question sentence pairs , collected annotated research open-domain question answering . order reflect true information need general users , used bing query logs question source . question linked wikipedia page potentially answer . summary section wikipedia page provides basic usually important information topic , used sentences section candidate answers . help crowdsourcing , included , questions , sentences dataset , , sentences labeled answer sentences corresponding questions . detail corpus found emnlp- paper , `` wikiqa : challenge dataset open-domain question answering `` [ yang et al . ] . addition , download also includes experimental results paper , evaluation script judging `` answer triggering `` task , well answer phrases labeled authors paper .'

# %%
sent_ment = SentimentIntensityAnalyzer()

# %%
sent_score = sent_ment.polarity_scores(sent)

# %%
sent_score
# Out:
# {'neg': 0.0, 'neu': 0.84, 'pos': 0.16, 'compound': 0.8689}

# %%
sent_score['compound']
# Out:
# 0.8689

# %% [markdown]
# # Word Cloud

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/f5/b0/247159f61c5d5d6647171bef84430b7efad4db504f0229674024f3a4f7f2/wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata
#   Using cached wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\hp\anaconda3\lib\site-packages (from wordcloud) (1.26.2)
# Requirement already satisfied: pillow in c:\users\hp\anaconda3\lib\site-packages (from wordcloud) (10.0.1)
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Using cached wordcloud-1.9.3-cp311-cp311-win_amd64.whl (300 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
w_c = WordCloud(width=1000,height=500,background_color="green").generate(sent)

plt.figure(figsize=(14,6))
plt.imshow(w_c)
plt.axis('off')
plt.show()

# %%
w_c

# %% [markdown]
# # Keyword extraction

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
input_text = 'wikiqa corpus new publicly available set question sentence pairs , collected annotated research open-domain question answering . order reflect true information need general users , used bing query logs question source . question linked wikipedia page potentially answer . summary section wikipedia page provides basic usually important information topic , used sentences section candidate answers . help crowdsourcing , included , questions , sentences dataset , , sentences labeled answer sentences corresponding questions . detail corpus found emnlp- paper , `` wikiqa : challenge dataset open-domain question answering `` [ yang et al . ] . addition , download also includes experimental results paper , evaluation script judging `` answer triggering `` task , well answer phrases labeled authors paper .'

# %%
vect = CountVectorizer(stop_words="english")

# %%
ext_val = vect.fit_transform([input_text])

# %%
vect.get_feature_names_out()
# Out:
# array(['addition', 'al', 'annotated', 'answer', 'answering', 'answers',
#        'authors', 'available', 'basic', 'bing', 'candidate', 'challenge',
#        'collected', 'corpus', 'corresponding', 'crowdsourcing', 'dataset',
#        'domain', 'download', 'emnlp', 'et', 'evaluation', 'experimental',
#        'general', 'help', 'important', 'included', 'includes',
#        'information', 'judging', 'labeled', 'linked', 'logs', 'need',
#        'new', 'open', 'order', 'page', 'pairs', 'paper', 'phrases',
#        'potentially', 'provides', 'publicly', 'query', 'question',
#        'questions', 'reflect', 'research', 'results', 'script', 'section',
#        'sentence', 'sentences', 'set', 'source', 'summary', 'task',
#        'topic', 'triggering', 'true', 'used', 'users', 'usually',
#        'wikipedia', 'wikiqa', 'yang'], dtype=object)

# %% [markdown]
# # Name Entity Recognition

# %%
import spacy

# %%
# Load spaCy English language model
nlp = spacy.load("en_core_web_sm")

# %%
# Sample text for NER
text ='wikiqa corpus new publicly available set question sentence pairs , collected annotated research open-domain question answering . order reflect true information need general users , used bing query logs question source . question linked wikipedia page potentially answer . summary section wikipedia page provides basic usually important information topic , used sentences section candidate answers . help crowdsourcing , included , questions , sentences dataset , , sentences labeled answer sentences corresponding questions . detail corpus found emnlp- paper , `` wikiqa : challenge dataset open-domain question answering `` [ yang et al . ] . addition , download also includes experimental results paper , evaluation script judging `` answer triggering `` task , well answer phrases labeled authors paper .'

# %%
doc = nlp(text)

# %%
for ent in doc.ents:
    print(f"Entity: {ent.text}, Type: {ent.label_}")
# Out:
# Entity: [ yang et al . ] ., Type: WORK_OF_ART
